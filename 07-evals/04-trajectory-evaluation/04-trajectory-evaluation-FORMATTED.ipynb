# %% [markdown]
# ## Trajectory Evaluation - Understanding How Agents Think and Execute Tasks
#
# This tutorial demonstrates how to evaluate agent trajectories - the sequences of tool calls, reasoning steps, and decisions agents make to complete tasks. Trajectory evaluation helps you understand not just what agents produce, but how they think and execute tasks.
#
# ### What You'll Learn
# - Understand agent trajectories (tool calls, reasoning steps, sequences)
# - Visualize execution trajectories (Session → Trace → Spans)
# - Use TrajectoryEvaluator with custom rubrics
# - Evaluate optimal, suboptimal, and incorrect trajectories
# - Implement trajectory scoring functions (exact_match, in_order, any_order)
# - Analyze HOW agents think, not just WHAT they produce
#
# ### Tutorial Details
#
# | Information         | Details                                                                       |
# |:--------------------|:----------------------------------------------------------------------------------|
# | Tutorial type       | Intermediate - Understanding and evaluating agent execution paths                 |
# | Tutorial components | Multi-agent system, TrajectoryEvaluator, trajectory visualization                |
# | Tutorial vertical   | Agent Evaluation                                                                  |
# | Example complexity  | Medium                                                                            |
# | SDK used            | Strands Agents, Strands Evals                                                     |

# %% [markdown]
# ### Understanding Trajectories
#
# A **trajectory** is the complete sequence of actions an agent takes to solve a task, including tool calls, reasoning steps, and execution flow.
#
# #### Why Evaluate Trajectories?
#
# | Output Evaluation Alone | Trajectory Evaluation Adds |
# |:------------------------|:---------------------------|
# | Multiple paths can produce same output | Shows efficiency of execution |
# | Can't detect inefficient reasoning | Reveals correctness of tool usage |
# | Misses optimization opportunities | Identifies where agent can improve |
#
# Use trajectory evaluation during development, optimization, and production monitoring to validate agent design and detect reasoning quality degradation.
#
# #### Trajectory Hierarchy
#
# ```
# Session → Trace (per invocation) → Spans (individual steps: tool calls, LLM calls)
# ```
#
# #### Three Trajectory Scenarios
#
# | Scenario | Description | Characteristics |
# |:---------|:------------|:----------------|
# | Optimal | Correct tools in correct order | Efficient, minimal steps, expected behavior |
# | Suboptimal | Extra or redundant steps | Correct answer but inefficient, redundant calls |
# | Incorrect | Wrong tools or wrong order | May produce wrong output, requires fixes |

# %%
import os

# %% [markdown]
# ### Environment Setup
#
# Configure AWS region and model settings for this tutorial.

# %%
import boto3

# AWS Configuration (inline - no config.py)
session = boto3.Session()
AWS_REGION = session.region_name or 'us-east-1'
DEFAULT_MODEL = 'us.anthropic.claude-3-7-sonnet-20250219-v1:0'

# %% [markdown]
# ### Setup and Imports
#
# Import all necessary libraries for agent creation, trajectory evaluation, and visualization.

# %%
# Standard imports
from typing import List, Dict, Any

# Strands imports
from strands import Agent
from strands.multiagent import GraphBuilder

# Strands Evals imports
from strands_evals import Dataset, Case
from strands_evals.evaluators import TrajectoryEvaluator

# Display utilities
from IPython.display import Markdown, display

# %% [markdown]
# ### Multi-Agent System for Trajectory Analysis
#
# We'll create a multi-agent business decision system with parallel execution. This system demonstrates clear trajectory patterns as different agents collaborate on analysis tasks.
#
# #### Architecture
#
# ```
# financial_advisor (entry)
#      ├──> technical_architect ──┐
#      └──> market_researcher ────┴──> risk_analyst (final)
# ```
#
# #### Agent Code
#
# Multi-agent code adapted from: /strands-samples/01-tutorials/02-multi-agent-systems/03-graph-agent/

# %%
# Create specialized agents for parallel analysis
financial_advisor = Agent(
    name="financial_advisor",
    system_prompt="You are a financial advisor focused on cost-benefit analysis, budget implications, and ROI calculations. Provide concise financial assessment in 2-3 sentences.",
    model=DEFAULT_MODEL
)

technical_architect = Agent(
    name="technical_architect",
    system_prompt="You are a technical architect who evaluates feasibility, implementation challenges, and technical risks. Provide concise technical assessment in 2-3 sentences.",
    model=DEFAULT_MODEL
)

market_researcher = Agent(
    name="market_researcher",
    system_prompt="You are a market researcher who analyzes market conditions, user needs, and competitive landscape. Provide concise market assessment in 2-3 sentences.",
    model=DEFAULT_MODEL
)

risk_analyst = Agent(
    name="risk_analyst",
    system_prompt="You are a risk analyst who synthesizes input from finance, technical, and market experts to identify potential risks and provide a final recommendation in 2-3 sentences.",
    model=DEFAULT_MODEL
)

# Build the agent graph with parallel execution
builder = GraphBuilder()

# Add nodes
builder.add_node(financial_advisor, "finance_expert")
builder.add_node(technical_architect, "tech_expert")
builder.add_node(market_researcher, "market_expert")
builder.add_node(risk_analyst, "risk_analyst")

# Add edges - parallel execution pattern
builder.add_edge("finance_expert", "tech_expert")
builder.add_edge("finance_expert", "market_expert")
builder.add_edge("tech_expert", "risk_analyst")
builder.add_edge("market_expert", "risk_analyst")

# Set entry point
builder.set_entry_point("finance_expert")

# Build the graph
decision_graph = builder.build()
# Out:
# Graph without execution limits may run indefinitely if cycles exist

# %% [markdown]
# ### Test the Multi-Agent System
#
# Before evaluating trajectories, let's verify the system works and examine its execution flow.

# %%
# Test the multi-agent system
test_query = "Should we invest $500K in developing an AI-powered customer service chatbot?"
result = decision_graph(test_query)

print(f"\nFinal Decision: {result}\n")
print("="*80)

# Show execution flow
print("\nExecution Order (Trajectory):")
for node in result.execution_order:
    print(f"  - {node.node_id}")
# Out:
# Without specific ROI projections, this $500K chatbot investment requires careful evaluation. Consider comparing anticipated cost savings (reduced customer service headcount, extended service hours) against implementation costs, ongoing maintenance, and potential customer experience impacts. I'd recommend a phased implementation approach with clear success metrics to validate the return before full deployment.BaseFromd on the market a technical architecture perspective, implementing an AI-powere analysis, AI-powered customer service chatbots are becoming increasingly mainstream with strong adoption trends across industries as businesses seek to reduce operational costs while maintaining service quality. Currentd customer service chatbot involves significant complexity in natural language processing, integration with existing customer service systems, and knowledge base development. The $500K budget appears adequate for initial development but may customer expectations increasingly accept not cover comprehensive training automated solutions for routine inquiries,, ongoing optimization, and maintenance costs though the competitive required for high-quality customer interactions landscape shows varying degrees of sophist. Consider a phased implementationication and effectiveness with clear technical among existing solutions success metrics to validate performance before full deployment.. Before investing $500K, I recommend benchmarking against current market leaders and identifying specific customer pain points your solution would address more effectively than competitors.# Risk Analysis and Final Recommendation
#
# Based on the inputs from market and technical experts, I've identified the following key risks:
#
# 1. **Market saturation risk**: AI chatbots are becoming mainstream, requiring clear differentiation to succeed
# 2. **Technical complexity risk**: NLP challenges and integration with existing systems could lead to implementation difficulties
# 3. **Budget adequacy risk**: The $500K may cover initial development but likely not ongoing maintenance and optimization
# 4. **Customer experience risk**: Suboptimal implementation could negatively impact customer satisfaction
# 5. **ROI uncertainty**: Without benchmarking against competitors and establishing clear metrics, return on investment remains unclear
#
# **Final Recommendation**: Proceed with the investment but implement a phased approach with clear success metrics at each stage, beginning with a limited proof-of-concept that targets specific high-value customer pain points, while establishing comprehensive total cost of ownership projections including ongoing maintenance and optimization costs.
# Final Decision: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "Without specific ROI projections, this $500K chatbot investment requires careful evaluation. Consider comparing anticipated cost savings (reduced customer service headcount, extended service hours) against implementation costs, ongoing maintenance, and potential customer experience impacts. I'd recommend a phased implementation approach with clear success metrics to validate the return before full deployment."}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[2.778975009918213], traces=[<strands.telemetry.metrics.Trace object at 0x1309cf920>], accumulated_usage={'inputTokens': 58, 'outputTokens': 70, 'totalTokens': 128}, accumulated_metrics={'latencyMs': 2449}), state={}, interrupts=None, structured_output=None), execution_time=2779, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 58, 'outputTokens': 70, 'totalTokens': 128}, accumulated_metrics={'latencyMs': 2449}, execution_count=1), 'tech_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'From a technical architecture perspective, implementing an AI-powered customer service chatbot involves significant complexity in natural language processing, integration with existing customer service systems, and knowledge base development. The $500K budget appears adequate for initial development but may not cover comprehensive training, ongoing optimization, and maintenance costs required for high-quality customer interactions. Consider a phased implementation with clear technical success metrics to validate performance before full deployment.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[2.5864768028259277], traces=[<strands.telemetry.metrics.Trace object at 0x1309cfa10>], accumulated_usage={'inputTokens': 143, 'outputTokens': 86, 'totalTokens': 229}, accumulated_metrics={'latencyMs': 2259}), state={}, interrupts=None, structured_output=None), execution_time=2587, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 143, 'outputTokens': 86, 'totalTokens': 229}, accumulated_metrics={'latencyMs': 2259}, execution_count=1), 'market_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Based on the market analysis, AI-powered customer service chatbots are becoming increasingly mainstream with strong adoption trends across industries as businesses seek to reduce operational costs while maintaining service quality. Current customer expectations increasingly accept automated solutions for routine inquiries, though the competitive landscape shows varying degrees of sophistication and effectiveness among existing solutions. Before investing $500K, I recommend benchmarking against current market leaders and identifying specific customer pain points your solution would address more effectively than competitors.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[3.0836310386657715], traces=[<strands.telemetry.metrics.Trace object at 0x11731d9a0>], accumulated_usage={'inputTokens': 143, 'outputTokens': 97, 'totalTokens': 240}, accumulated_metrics={'latencyMs': 2755}), state={}, interrupts=None, structured_output=None), execution_time=3084, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 143, 'outputTokens': 97, 'totalTokens': 240}, accumulated_metrics={'latencyMs': 2755}, execution_count=1), 'risk_analyst': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Risk Analysis and Final Recommendation\n\nBased on the inputs from market and technical experts, I've identified the following key risks:\n\n1. **Market saturation risk**: AI chatbots are becoming mainstream, r ...
#
# ================================================================================
#
# Execution Order (Trajectory):
#   - finance_expert
#   - tech_expert
#   - market_expert
#   - risk_analyst

# %% [markdown]
# ### Understanding Trajectory Scoring Functions
#
# | Scorer | Use Case | Scoring Logic |
# |:-------|:---------|:--------------|
# | **Exact Match** | Strict compliance (medical, financial) | 1.0 if exact sequence, 0.0 otherwise |
# | **In-Order Match** | Sequence matters, extra steps OK | Proportion of expected steps in correct order |
# | **Any-Order Match** | Only presence matters | Proportion of expected steps present |
#
# #### Implementation

# %%
def exact_match_scorer(expected_trajectory: List[str], actual_trajectory: List[str]) -> float:
    """
    Score 1.0 if trajectories match exactly, 0.0 otherwise.
    
    Args:
        expected_trajectory: List of expected step identifiers
        actual_trajectory: List of actual step identifiers from execution
    
    Returns:
        1.0 if exact match, 0.0 otherwise
    """
    return 1.0 if expected_trajectory == actual_trajectory else 0.0


def in_order_match_scorer(expected_trajectory: List[str], actual_trajectory: List[str]) -> float:
    """
    Score based on proportion of expected steps present in correct order.
    Extra steps are allowed but don't affect score.
    
    Args:
        expected_trajectory: List of expected step identifiers
        actual_trajectory: List of actual step identifiers from execution
    
    Returns:
        Proportion of expected steps found in order (0.0 to 1.0)
    """
    if not expected_trajectory:
        return 1.0
    
    expected_idx = 0
    matches = 0
    
    for actual_step in actual_trajectory:
        if expected_idx < len(expected_trajectory) and actual_step == expected_trajectory[expected_idx]:
            matches += 1
            expected_idx += 1
    
    return matches / len(expected_trajectory)


def any_order_match_scorer(expected_trajectory: List[str], actual_trajectory: List[str]) -> float:
    """
    Score based on proportion of expected steps present, regardless of order.
    
    Args:
        expected_trajectory: List of expected step identifiers
        actual_trajectory: List of actual step identifiers from execution
    
    Returns:
        Proportion of expected steps found (0.0 to 1.0)
    """
    if not expected_trajectory:
        return 1.0
    
    actual_set = set(actual_trajectory)
    matches = sum(1 for step in expected_trajectory if step in actual_set)
    
    return matches / len(expected_trajectory)

# %% [markdown]
# ### Trajectory Extraction Helper
#
# Create a helper function to extract trajectories from agent execution results.

# %%
def extract_trajectory(result) -> List[str]:
    """
    Extract the execution trajectory from a graph result.
    
    Args:
        result: Graph execution result
    
    Returns:
        List of node IDs in execution order
    """
    return [node.node_id for node in result.execution_order]

# %% [markdown]
# ### Scenario 1: Optimal Trajectory
#
# An optimal trajectory uses the correct tools in the correct order with minimal steps. This represents the expected, efficient execution path.
#
# #### Expected Trajectory
# ```
# finance_expert → tech_expert → market_expert → risk_analyst
# ```
#
# This is the natural flow for our multi-agent decision system.

# %%
# Define optimal test case
optimal_case = Case(
    name="Optimal Decision Path",
    input="Should we invest $1M in expanding our cloud infrastructure to support 10x user growth?",
    expected_output="A comprehensive analysis considering financial, technical, and market factors with a clear recommendation."
)

# Expected trajectory for this case
expected_optimal_trajectory = [
    "finance_expert",
    "tech_expert",
    "market_expert",
    "risk_analyst"
]

print(f"\nExpected trajectory: {' → '.join(expected_optimal_trajectory)}")
# Out:
# Expected trajectory: finance_expert → tech_expert → market_expert → risk_analyst

# %%
# Execute the optimal case
optimal_result = decision_graph(optimal_case.input)
optimal_trajectory = extract_trajectory(optimal_result)

print(f"\nInput: {optimal_case.input}")
print(f"\nFinal Output: {optimal_result}")
print("\n" + "="*80)
print("\nTrajectory Analysis:")
print(f"  Expected: {' → '.join(expected_optimal_trajectory)}")
print(f"  Actual:   {' → '.join(optimal_trajectory)}")

# Score the trajectory
exact_score = exact_match_scorer(expected_optimal_trajectory, optimal_trajectory)
in_order_score = in_order_match_scorer(expected_optimal_trajectory, optimal_trajectory)
any_order_score = any_order_match_scorer(expected_optimal_trajectory, optimal_trajectory)

print(f"\nTrajectory Scores:")
print(f"  Exact Match:    {exact_score:.2f} (requires exact sequence)")
print(f"  In-Order Match: {in_order_score:.2f} (allows extra steps)")
print(f"  Any-Order Match: {any_order_score:.2f} (ignores order)")

# Interpretation
if exact_score == 1.0:
    interpretation = "**OPTIMAL**: Trajectory perfectly matches expected path"
elif in_order_score >= 0.75:
    interpretation = "**GOOD**: Most expected steps present in correct order"
else:
    interpretation = "**SUBOPTIMAL**: Significant deviations from expected path"

print(f"\nInterpretation: {interpretation}")
# Out:
# This $1M cloud infrastructure investment appears justified if your user growth projections are supported by reliable data, as insufficient capacity could result in lost revenue and damaged reputation. Calculate the expected incremental revenue from the additional users against the total cost of ownership, including not just the upfront investment but ongoing operational expenses. Consider a staged expansion approach that allows scaling in response to actual growth patterns rather than committing the full amount upfront.From a technical architecture standpoint, scaling clouMarketd infrastructure for 10x user growth requires not just expanded capacity but potentially analysis indicates cloud infrastructure solutions are experiencing robust growth with increasing re-architecting applications for horizontal scalability an customer expectations for seamless scald implementing robust autoability and zero downtime as-scaling mechanisms. The $1M investment should cover standard requirements. Competitors infrastructure expansion are actively investing in similar expans but may neeions to support larger user bases, making this capability table stakes rather than a differd additional allocation for potential application refentiator in mostactoring, enhanced monitoring market segments. The decision should be driven by validate systems, and performanced growth forecasts an optimization work. I recommend a phd customer retention risks,ased scaling approach with clear technical milestones to ensure as market trends suggest users the architecture remains resilient and cost- quickly abandon platforms experiencing performanceeffective throughout the growth curve. issues during scaling events.# Risk Analysis and Final Recommendation
#
# Based on the inputs from market and technical experts, I've identified the following key risks:
#
# 1. **Growth forecast risk**: The investment assumes 10x growth that may not materialize as projected
# 2. **Technical refactoring risk**: Additional costs beyond the $1M may be required for application redesign to support horizontal scaling
# 3. **Competition parity risk**: This investment represents table stakes rather than competitive advantage
# 4. **Customer retention risk**: Failure to scale effectively could result in significant user abandonment
# 5. **Cost optimization risk**: Without phased implementation, the infrastructure might be overprovisioned relative to actual growth
#
# **Final Recommendation**: Approve the $1M investment with a phased implementation approach tied to actual growth metrics, but allocate additional contingency budget for potential application refactoring needs, and establish clear technical and business KPIs at each scaling milestone to ensure the expansion remains aligned with actual user growth patterns.
# Input: Should we invest $1M in expanding our cloud infrastructure to support 10x user growth?
#
# Final Output: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'This $1M cloud infrastructure investment appears justified if your user growth projections are supported by reliable data, as insufficient capacity could result in lost revenue and damaged reputation. Calculate the expected incremental revenue from the additional users against the total cost of ownership, including not just the upfront investment but ongoing operational expenses. Consider a staged expansion approach that allows scaling in response to actual growth patterns rather than committing the full amount upfront.'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[2.778975009918213, 2.873323917388916], traces=[<strands.telemetry.metrics.Trace object at 0x1309cf920>, <strands.telemetry.metrics.Trace object at 0x130246810>], accumulated_usage={'inputTokens': 208, 'outputTokens': 159, 'totalTokens': 367}, accumulated_metrics={'latencyMs': 5220}), state={}, interrupts=None, structured_output=None), execution_time=2874, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 208, 'outputTokens': 159, 'totalTokens': 367}, accumulated_metrics={'latencyMs': 5220}, execution_count=1), 'tech_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'From a technical architecture standpoint, scaling cloud infrastructure for 10x user growth requires not just expanded capacity but potentially re-architecting applications for horizontal scalability and implementing robust auto-scaling mechanisms. The $1M investment should cover infrastructure expansion but may need additional allocation for potential application refactoring, enhanced monitoring systems, and performance optimization work. I recommend a phased scaling approach with clear technical milestones to ensure the architecture remains resilient and cost-effective throughout the growth curve.'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[2.5864768028259277, 3.274427890777588], traces=[<strands.telemetry.metrics.Trace object at 0x1309cfa10>, <strands.telemetry.metrics.Trace object at 0x130246b10>], accumulated_usage={'inputTokens': 500, 'outputTokens': 188, 'totalTokens': 688}, accumulated_metrics={'latencyMs': 5428}), state={}, interrupts=None, structured_output=None), execution_time=3275, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 500, 'outputTokens': 188, 'totalTokens': 688}, accumulated_metrics={'latencyMs': 5428}, execution_count=1), 'market_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Market analysis indicates cloud infrastructure solutions are experiencing robust growth with increasing customer expectations for seamless scalability and zero downtime as standard requirements. Competitors are actively investing in similar expansions to support larger user bases, making this capability table stakes rather than a differentiator in most market segments. The decision should be driven by validated growth forecasts and customer retention risks, as market trends suggest users quickly abandon platforms experiencing performance issues during scaling events.'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[3.0836310386657715, 3.3101611137390137], traces=[<strands.telemetry.metrics.Trace object at 0x11731d9a0>, <strands.telemetry.metrics.Trace object at 0x1302476e0>], accumulated_usage={'inputTokens': 511, 'outputTokens': 188, 'totalTokens': 699}, accumulated_metrics={'latencyMs': 5960}), state={}, interrupts=None, structured_output=None), execution_time=3310, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 511, 'outputTokens': 188, 'totalTokens': 699}, accumulated_metrics={'latencyMs': 5960}, execution_c ...
#
# ================================================================================
#
# Trajectory Analysis:
#   Expected: finance_expert → tech_expert → market_expert → risk_analyst
#   Actual:   finance_expert → tech_expert → market_expert → risk_analyst
#
# Trajectory Scores:
#   Exact Match:    1.00 (requires exact sequence)
#   In-Order Match: 1.00 (allows extra steps)
#   Any-Order Match: 1.00 (ignores order)
#
# Interpretation: **OPTIMAL**: Trajectory perfectly matches expected path

# %% [markdown]
# ### Scenario 2: Suboptimal Trajectory
#
# A suboptimal trajectory reaches the correct answer but takes unnecessary steps or makes redundant tool calls. This might indicate inefficiency or confusion in the agent's decision-making.
#
# #### Simulation Note
# Since our graph agent follows a deterministic execution pattern, we'll simulate a suboptimal trajectory by analyzing what it would look like if the agent made redundant calls.

# %%
# Simulate a suboptimal trajectory scenario
suboptimal_case = Case(
    name="Suboptimal Decision Path - Extra Analysis Steps",
    input="Evaluate a $250K investment in updating our mobile app with new features.",
    expected_output="A comprehensive analysis with clear recommendation."
)

# Expected optimal trajectory
expected_suboptimal_trajectory = [
    "finance_expert",
    "tech_expert",
    "market_expert",
    "risk_analyst"
]

# Simulate what a suboptimal trajectory might look like with redundant steps
# In a real scenario, this might happen if agent repeats analysis or backtracks
simulated_suboptimal_trajectory = [
    "finance_expert",
    "finance_expert",  # Redundant call
    "tech_expert",
    "market_expert",
    "market_expert",   # Redundant call
    "risk_analyst"
]

print("Suboptimal trajectory scenario defined")
print(f"\nExpected optimal: {' → '.join(expected_suboptimal_trajectory)}")
print(f"Simulated actual: {' → '.join(simulated_suboptimal_trajectory)}")
print("\nNote: Simulated trajectory shows redundant calls to finance_expert and market_expert")
# Out:
# Suboptimal trajectory scenario defined
#
# Expected optimal: finance_expert → tech_expert → market_expert → risk_analyst
# Simulated actual: finance_expert → finance_expert → tech_expert → market_expert → market_expert → risk_analyst
#
# Note: Simulated trajectory shows redundant calls to finance_expert and market_expert

# %%
# Analyze the suboptimal trajectory
print(f"\nCase: {suboptimal_case.name}")
print(f"Input: {suboptimal_case.input}")
print("\n" + "="*80)
print("\nTrajectory Analysis:")
print(f"  Expected: {' → '.join(expected_suboptimal_trajectory)}")
print(f"  Simulated: {' → '.join(simulated_suboptimal_trajectory)}")

# Score the simulated trajectory
exact_score = exact_match_scorer(expected_suboptimal_trajectory, simulated_suboptimal_trajectory)
in_order_score = in_order_match_scorer(expected_suboptimal_trajectory, simulated_suboptimal_trajectory)
any_order_score = any_order_match_scorer(expected_suboptimal_trajectory, simulated_suboptimal_trajectory)

print(f"\nTrajectory Scores:")
print(f"  Exact Match:    {exact_score:.2f} (requires exact sequence)")
print(f"  In-Order Match: {in_order_score:.2f} (allows extra steps)")
print(f"  Any-Order Match: {any_order_score:.2f} (ignores order)")

# Analysis
analysis = """
**Analysis of Suboptimal Trajectory:**

- **Exact Match: 0.00** - Trajectory doesn't match expected sequence exactly
- **In-Order Match: 1.00** - All expected steps are present in correct order (redundant steps ignored)
- **Any-Order Match: 1.00** - All expected steps are present

**Key Observations:**
- Redundant calls to finance_expert (called twice)
- Redundant calls to market_expert (called twice)
- Total steps: 6 (expected 4)
- Efficiency: 67% (4/6 necessary steps)

**Impact:**
- Increased latency (extra LLM calls)
- Higher costs (more token usage)
- Correct final output but inefficient path

**Recommendations:**
- Investigate why redundant calls occur
- Add caching or memoization for repeated analyses
- Review agent orchestration logic
"""

display(Markdown(analysis))
# Out:
# Case: Suboptimal Decision Path - Extra Analysis Steps
# Input: Evaluate a $250K investment in updating our mobile app with new features.
#
# ================================================================================
#
# Trajectory Analysis:
#   Expected: finance_expert → tech_expert → market_expert → risk_analyst
#   Simulated: finance_expert → finance_expert → tech_expert → market_expert → market_expert → risk_analyst
#
# Trajectory Scores:
#   Exact Match:    0.00 (requires exact sequence)
#   In-Order Match: 1.00 (allows extra steps)
#   Any-Order Match: 1.00 (ignores order)
# **Analysis of Suboptimal Trajectory:**
#
# - **Exact Match: 0.00** - Trajectory doesn't match expected sequence exactly
# - **In-Order Match: 1.00** - All expected steps are present in correct order (redundant steps ignored)
# - **Any-Order Match: 1.00** - All expected steps are present
#
# **Key Observations:**
# - Redundant calls to finance_expert (called twice)
# - Redundant calls to market_expert (called twice)
# - Total steps: 6 (expected 4)
# - Efficiency: 67% (4/6 necessary steps)
#
# **Impact:**
# - Increased latency (extra LLM calls)
# - Higher costs (more token usage)
# - Correct final output but inefficient path
#
# **Recommendations:**
# - Investigate why redundant calls occur
# - Add caching or memoization for repeated analyses
# - Review agent orchestration logic

# %% [markdown]
# ### Scenario 3: Incorrect Trajectory
#
# An incorrect trajectory uses wrong tools or wrong order, potentially leading to incorrect outputs. This might indicate fundamental issues with agent design or understanding.
#
# #### Simulation Note
# We'll simulate an incorrect trajectory where the agent skips critical analysis steps or uses tools in wrong order.

# %%
# Simulate an incorrect trajectory scenario
incorrect_case = Case(
    name="Incorrect Decision Path - Missing Critical Analysis",
    input="Should we acquire a competitor for $5M?",
    expected_output="A comprehensive analysis covering all decision factors."
)

# Expected optimal trajectory
expected_incorrect_trajectory = [
    "finance_expert",
    "tech_expert",
    "market_expert",
    "risk_analyst"
]

# Simulate what an incorrect trajectory might look like
# Missing market analysis and jumping straight to risk assessment
simulated_incorrect_trajectory = [
    "finance_expert",
    "risk_analyst",     # Wrong: skipped technical and market analysis
    "tech_expert"       # Wrong: analyzing after making risk decision
]

print("Incorrect trajectory scenario defined")
print(f"\nExpected: {' → '.join(expected_incorrect_trajectory)}")
print(f"Simulated: {' → '.join(simulated_incorrect_trajectory)}")
print("\nNote: Simulated trajectory skips market_expert and analyzes in wrong order")
# Out:
# Incorrect trajectory scenario defined
#
# Expected: finance_expert → tech_expert → market_expert → risk_analyst
# Simulated: finance_expert → risk_analyst → tech_expert
#
# Note: Simulated trajectory skips market_expert and analyzes in wrong order

# %%
# Analyze the incorrect trajectory
print(f"\nCase: {incorrect_case.name}")
print(f"Input: {incorrect_case.input}")
print("\n" + "="*80)
print("\nTrajectory Analysis:")
print(f"  Expected: {' → '.join(expected_incorrect_trajectory)}")
print(f"  Simulated: {' → '.join(simulated_incorrect_trajectory)}")

# Score the simulated trajectory
exact_score = exact_match_scorer(expected_incorrect_trajectory, simulated_incorrect_trajectory)
in_order_score = in_order_match_scorer(expected_incorrect_trajectory, simulated_incorrect_trajectory)
any_order_score = any_order_match_scorer(expected_incorrect_trajectory, simulated_incorrect_trajectory)

print(f"\nTrajectory Scores:")
print(f"  Exact Match:    {exact_score:.2f} (requires exact sequence)")
print(f"  In-Order Match: {in_order_score:.2f} (allows extra steps)")
print(f"  Any-Order Match: {any_order_score:.2f} (ignores order)")

# Analysis
analysis = """
**Analysis of Incorrect Trajectory:**

- **Exact Match: 0.00** - Completely different sequence
- **In-Order Match: 0.50** - Only 2 of 4 expected steps present in order (finance_expert, tech_expert)
- **Any-Order Match: 0.50** - Only 2 of 4 expected steps present (missing market_expert)

**Key Observations:**
- **Missing step**: market_expert analysis completely skipped
- **Wrong order**: risk_analyst called before tech_expert
- **Incomplete analysis**: Decision made without market perspective
- Coverage: 50% (2/4 critical analyses performed)

**Critical Issues:**
1. **Missing market analysis**: No competitive or demand assessment
2. **Premature risk decision**: Made before gathering all inputs
3. **Wrong execution order**: Technical analysis after risk assessment is too late

**Impact:**
- **High risk**: Decision made without complete information
- **Low confidence**: Missing critical market perspective
- **Potential errors**: Risk analysis based on incomplete data

**Recommendations:**
- **Critical fix required**: Ensure all required analyses are performed
- Review orchestration logic to enforce dependencies
- Add validation checks before risk assessment
- Consider making market analysis a hard requirement
"""

display(Markdown(analysis))
# Out:
# Case: Incorrect Decision Path - Missing Critical Analysis
# Input: Should we acquire a competitor for $5M?
#
# ================================================================================
#
# Trajectory Analysis:
#   Expected: finance_expert → tech_expert → market_expert → risk_analyst
#   Simulated: finance_expert → risk_analyst → tech_expert
#
# Trajectory Scores:
#   Exact Match:    0.00 (requires exact sequence)
#   In-Order Match: 0.50 (allows extra steps)
#   Any-Order Match: 0.75 (ignores order)
# **Analysis of Incorrect Trajectory:**
#
# - **Exact Match: 0.00** - Completely different sequence
# - **In-Order Match: 0.50** - Only 2 of 4 expected steps present in order (finance_expert, tech_expert)
# - **Any-Order Match: 0.50** - Only 2 of 4 expected steps present (missing market_expert)
#
# **Key Observations:**
# - **Missing step**: market_expert analysis completely skipped
# - **Wrong order**: risk_analyst called before tech_expert
# - **Incomplete analysis**: Decision made without market perspective
# - Coverage: 50% (2/4 critical analyses performed)
#
# **Critical Issues:**
# 1. **Missing market analysis**: No competitive or demand assessment
# 2. **Premature risk decision**: Made before gathering all inputs
# 3. **Wrong execution order**: Technical analysis after risk assessment is too late
#
# **Impact:**
# - **High risk**: Decision made without complete information
# - **Low confidence**: Missing critical market perspective
# - **Potential errors**: Risk analysis based on incomplete data
#
# **Recommendations:**
# - **Critical fix required**: Ensure all required analyses are performed
# - Review orchestration logic to enforce dependencies
# - Add validation checks before risk assessment
# - Consider making market analysis a hard requirement

# %% [markdown]
# ### Trajectory Evaluation with TrajectoryEvaluator
#
# Now let's use the built-in TrajectoryEvaluator to automatically evaluate trajectories. The TrajectoryEvaluator uses LLM-based assessment to score trajectory quality.

# %%
# Create custom rubric for trajectory evaluation
trajectory_rubric = """
Evaluate the agent's execution trajectory based on the following criteria:

Score 1 (Poor):
- Missing critical analysis steps
- Wrong order of operations
- Skipped essential expert consultations
- Incomplete information gathering

Score 2 (Fair):
- Some required steps present but incomplete
- Partially correct order
- Missing one key analysis
- Redundant or inefficient steps

Score 3 (Good):
- Most required steps present
- Generally correct order
- Minor inefficiencies acceptable
- All critical analyses performed

Score 4 (Very Good):
- All required steps present
- Correct order maintained
- Efficient execution
- Proper expert collaboration

Score 5 (Excellent):
- Optimal execution path
- Perfect order and completeness
- No unnecessary steps
- Maximum efficiency and correctness
"""

# Create TrajectoryEvaluator with custom rubric
trajectory_evaluator = TrajectoryEvaluator(
    rubric=trajectory_rubric,
    model=DEFAULT_MODEL, 
    include_inputs=True
)

# %%
# Create evaluation dataset with all three scenarios
evaluation_cases = [
    optimal_case,
    suboptimal_case,
    incorrect_case
]

dataset = Dataset(
    cases=evaluation_cases,
    evaluator=trajectory_evaluator
)

# %%
# Define agent task function for evaluation
def agent_task(case: Case) -> dict:
    """
    Execute the multi-agent decision system and return the result with trajectory.
    """
    result = decision_graph(case.input)
    
    return {
        "output": str(result),
        "trajectory": [node.node_id for node in result.execution_order]
    }

# %%
# Run trajectory evaluation
report = dataset.run_evaluations(agent_task)
# Out:
# This $1M cloud infrastructure investment appears justified if your user growth projections are supported by reliable data, as insufficient capacity could result in lost revenue and damaged reputation. Consider a staged expansion approach that allows scaling in response to actual growth patterns rather than committing the full amount upfront.TheFrom a technical architecture cloud infrastructure market continues to experience standpoint, scaling cloud infrastructure for 10 double-digit growth withx user growth requires not just expanded capacity escalating customer demands for but potentially re-architecting applications for reliability and performance horizontal scalability and implementing robust auto- during usage spikes.scaling mechanisms. The $1M investment Competitors across industries are prioritizing similar infrastructure investments to maintain competitive p appears reasonable but should include provisions forarity, with many adop application refactoring toting elastic solutions that scale dynamically with demand. Current prevent bottlenecks as user behavior trends indicate decreasing tolerance for lat scale increases. Consider implementing a microservices architecture withency or availability issues, suggesting that containerization to enable infrastructure constraints could significantly impact customer retention more granular an and market position if your growth projections materd cost-efficient scaling patternsialize..# Risk Analysis and Final Recommendation
#
# Based on the inputs from market and technical experts, I've identified the following key risks:
#
# 1. **Competitive positioning risk**: Failure to scale infrastructure could significantly damage market position as competitors are making similar investments
# 2. **Architecture redesign risk**: Current applications may require substantial refactoring to support horizontal scaling, potentially exceeding planned budget
# 3. **Customer retention risk**: Increasing user intolerance for performance issues could lead to customer exodus if infrastructure fails to scale smoothly
# 4. **Cost efficiency risk**: Without adopting modern architectures like microservices and containerization, scaling costs may become prohibitively expensive
# 5. **Implementation timing risk**: Delays in infrastructure expansion could create performance bottlenecks if growth occurs faster than anticipated
#
# **Final Recommendation**: Approve the $1M investment but implement a two-track approach: immediately expand raw capacity while simultaneously initiating application refactoring toward microservices architecture, with clearly defined performance metrics and incremental deployment milestones to ensure scaling remains ahead of actual user growth curves.The $250K mobile app update should be evaluated against expected incremental revenue or improved user retention metrics that would result from the new features. Conduct competitive analysis to determine if these updates are necessary to maintain market position or if they provide genuine differentiation that will drive measurable business outcomes.From a technical architectureMarket research perspective, updating a mobile app with new features requires careful evaluation of the current c shows mobile app engagement is increasingly criticalodebase quality, technical debt, and compatibility with modern to customer retention, with 70% of development frameworks. The $250 users abandoning apps that donK budget may be insufficient if the existing't regularly update with competitive features. The app architecture needs significant refactoring alongside app marketplace has become highly new feature development. Consider conducting a technical audit first to identify potential sophisticated with users expecting frequent implementation risks and determine updates, intuitive design, an whether a phased approach ord seamless functionality as complete rebuild would provide standard requirements rather than differ better long-term technicalentiators. Your competitors sustainability. have been averaging quarterly feature updates, creating potential market share vulnerability if your app appears stagnant in comparison to more actively developed alternatives.# Risk Analysis and Final Recommendation
#
# Based on the inputs from market and technical experts, I've identified the following key risks:
#
# 1. **Market positioning risk**: Failure to update the app regularly could lead to significant user abandonment (70% according to market data) and competitive disadvantage
# 2. **Budget adequacy risk**: The $250K allocation may be insufficient if significant technical debt or architectural issues exist in the current codebase
# 3. **Implementation scope risk**: Without a technical audit, it's unclear whether the planned features can be effectively integrated into the existing architecture
# 4. **Opportunity cost risk**: Investing in new features without addressing underlying technical issues may deliver short-term benefits but increase long-term costs
# 5. **User experience risk**: Poor implementation of new features could damage user perception more than having no new features
#
# **Final Recommendation**: Proceed with the investment but first allocate a portion (15-20%) for a comprehensive technical audit to determine whether the remaining budget should focus on targeted feature updates or a more substantial architectural improvement; phase implementation based on competitive analysis to prioritize features with highest retention impact while addressing critical technical debt.This $5M acquisition requires thorough due diligence on the competitor's financial health, customer base, technology assets, and potential synergies with your existing operations. Beyond the purchase price, factor in integration costs, potential customer churn, and cultural alignment challenges, while quantifying the strategic value of eliminating a competitor versus the alternative of investing that capital in organic growth initiatives.From a technical architecture standpoint, acquiring a competitor involvesCurrent complex system integration challenges market consolidation trends show increased M&A activity in that often exceed initial estimates. The $5 our sector with premiumM investment should include valuations being paid for companies budget for technical due diligence to assess code quality, technical debt, scal with complementary technology stability issues, and compatibility with your existing systemsacks or established customer bases. Analysis. Particular attention shoul of the competitive landscape indicatesd be paid to data this acquisition would significantly strengthen your market position by eliminating a key challenger while potentially providing access to new customer segments and intellectual migration complexity, potential redundancies in the technology stack, property assets. Customer sentiment and whether the competitor's research suggests minimal overlap in brand loyalty between your customer base architecture can be effectively and the competitor's, indicating potential for successful integration with merged or would require parallel limited churn risk. operation, significantly affecting the total integration timeline and cost.# Risk Analysis and Final Recommendation
#
# Based on the inputs from market and technical experts, I've identified the following key risks:
#
# 1. **Technical integration risk**: Complex system integrations often exceed initial time and cost estimates, potentially diminishing acquisition value
# 2. **Due diligence risk**: Insufficient technical assessment could reveal significant hidden technical debt post-acquisition
# 3. **Parallel operations risk**: Incompatible architectures might require maintaining two separate technology stacks, increasing operational costs
# 4. **Data migration risk**: Customer and operational data transfers between systems could lead to business disruption or data integrity issues
# 5. **Valuation risk**: The $5M price must be evaluated against both market positioning benefits and total cost of technical integration
#
# **Final Recommendation**: Conditionally approve the acquisition subject to comprehensive technical due diligence focusing on system compatibility, technical debt assessment, and data migration complexity; establish a detailed integration roadmap with clear milestones and additional budget allocations for technical integration challenges before finalizing the purchase price.

# %% [markdown]
# ### Evaluation Results
#
# Display the trajectory evaluation results with detailed analysis.

# %%
# Display evaluation report
report.run_display()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.87           Pass Rate: 1.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                          Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                                                ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Optimal Decision Path                               │ 0.90  │ ✅        │ ...    │ ...   │
# ├───────┼─────────────────────────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Suboptimal Decision Path - Extra Analysis Steps     │ 0.80  │ ✅        │ ...    │ ...   │
# ├───────┼─────────────────────────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 2   │ Incorrect Decision Path - Missing Critical Analysis │ 0.90  │ ✅        │ ...    │ ...   │
# └───────┴─────────────────────────────────────────────────────┴───────┴───────────┴────────┴───────┘
# Enter the test case number to expand/collapse it, o to expand all, and c to collapse all (q to quit).:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.87           Pass Rate: 1.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ index ┃ name                       ┃ score ┃ test_pass ┃ reason                    ┃ input                      ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ ▼ 0   │ Optimal Decision Path      │ 0.90  │ ✅        │ The trajectory shows an   │ Should we invest $1M in    │
# │       │                            │       │           │ excellent execution path  │ expanding our cloud        │
# │       │                            │       │           │ for analyzing the cloud   │ infrastructure to support  │
# │       │                            │       │           │ infrastructure investment │ 10x user growth?           │
# │       │                            │       │           │ question. The agent       │                            │
# │       │                            │       │           │ followed a logical        │                            │
# │       │                            │       │           │ sequence starting with    │                            │
# │       │                            │       │           │ 'finance_expert' to       │                            │
# │       │                            │       │           │ assess the financial      │                            │
# │       │                            │       │           │ viability, followed by    │                            │
# │       │                            │       │           │ 'market_expert' to        │                            │
# │       │                            │       │           │ understand industry       │                            │
# │       │                            │       │           │ trends and competitive    │                            │
# │       │                            │       │           │ positioning, then         │                            │
# │       │                            │       │           │ 'tech_expert' to evaluate │                            │
# │       │                            │       │           │ technical feasibility and │                            │
# │       │                            │       │           │ architecture              │                            │
# │       │                            │       │           │ considerations, and       │                            │
# │       │                            │       │           │ finally 'risk_analyst' to │                            │
# │       │                            │       │           │ synthesize all inputs     │                            │
# │       │                            │       │           │ into a comprehensive      │                            │
# │       │                            │       │           │ recommendation. This      │                            │
# │       │                            │       │           │ represents an optimal     │                            │
# │       │                            │       │           │ order of operations where │                            │
# │       │                            │       │           │ each expert builds on     │                            │
# │       │                            │       │           │ previous insights. The    │                            │
# │       │                            │       │           │ finance perspective       │                            │
# │       │                            │       │           │ properly comes first as   │                            │
# │       │                            │       │           │ the initial question is   │                            │
# │       │                            │       │           │ about a financial         │                            │
# │       │                            │       │           │ investment. Market        │                            │
# │       │                            │       │           │ analysis follows to       │                            │
# │       │                            │       │           │ validate the investment   │                            │
# │       │                            │       │           │ from a competitive        │                            │
# │       │                            │       │           │ standpoint. Technical     │                            │
# │       │                            │       │           │ expertise is then brought │                            │
# │       │                            │       │           │ in to assess              │                            │
# │       │                            │       │           │ implementation            │                            │
# │       │                            │       │           │ feasibility. The risk     │                            │
# │       │                            │       │           │ analyst appropriately     │                            │
# │       │                            │       │           │ comes last to integrate   │                            │
# │       │                            │       │           │ all perspectives into a   │                            │
# │       │                            │       │           │ final recommendation with │                            │
# │       │                            │       │           │ identified risks and      │                            │
# │       │                            │       │           │ mitigation strategies.    │                            │
# │       │                            │       │           │ There are no unnecessary  │                            │
# │       │                            │       │           │ steps or redundant        │                            │
# │       │                            │       │           │ consultations, and the    │                            │
# │       │                            │       │           │ flow demonstrates proper  │                            │
# │       │                            │       │           │ expert collaboration      │                            │
# │       │                            │       │           │ where each specialist     │                            │
# │       │                            │       │           │ contributes their domain  │                            │
# │       │                            │       │           │ knowledge to form a       │                            │
# │       │                            │       │           │ comprehensive analysis.   │                            │
# │       │                            │       │           │ The final output delivers │                            │
# │       │                            │       │           │ exactly what was expected │                            │
# │       │                            │       │           │ - a thorough analysis     │                            │
# │       │                            │       │           │ considering financial,    │                            │
# │       │                            │       │           │ technical, and market     │                            │
# │       │                            │       │           │ factors with a clear      │                            │
# │       │                            │       │           │ recommendation.           │                            │
# ├───────┼────────────────────────────┼───────┼───────────┼───────────────────────────┼────────────────────────────┤
# │ ▼ 1   │ Suboptimal Decision Path - │ 0.80  │ ✅        │ The agent's execution     │ Evaluate a $250K           │
# │       │ Extra Analysis Steps       │       │           │ trajectory shows a        │ investment in updating our │
# │       │                            │       │           │ well-structured approach  │ mobile app with new        │
# │       │                            │       │           │ to evaluating the mobile  │ features.                  │
# │       │                            │       │           │ app investment. The       │                            │
# │       │                            │       │           │ trajectory follows a      │                            │
# │       │                            │       │           │ logical sequence:         │                            │
# │       │                            │       │           │ starting with             │                            │
# │       │                            │       │           │ finance_expert to         │                            │
# │       │                            │       │           │ establish the financial   │                            │
# │       │                            │       │           │ evaluation criteria,      │                            │
# │       │                            │       │           │ followed by tech_expert   │                            │
# │       │                            │       │           │ to assess technical       │                            │
# │       │                            │       │           │ feasibility and           │                            │
# │       │                            │       │           │ challenges, market_expert │                            │
# │       │                            │       │           │ to provide competitive    │                            │
# │       │                            │       │           │ landscape analysis, and   │                            │
# │       │                            │       │           │ finally risk_analyst to   │                            │
# │       │                            │       │           │ synthesize all inputs and │                            │
# │       │                            │       │           │ provide a comprehensive   │                            │
# │       │                            │       │           │ recommendation.           │                            │
# │       │                            │       │           │                           │                            │
# │       │                            │       │           │ This execution path       │                            │
# │       │                            │       │           │ demonstrates proper       │                            │
# │       │                            │       │           │ expert collaboration with │                            │
# │       │                            │       │           │ each specialist building  │                            │
# │       │                            │       │           │ on previous analysis:     │                            │
# │       │                            │       │           │ 1. Finance expert         │                            │
# │       │                            │       │           │ established ROI metrics   │                            │
# │       │                            │       │           │ and competitive           │                            │
# │       │                            │       │           │ positioning needs         │                            │
# │       │                            │       │           │ 2. Tech expert evaluated  │                            │
# │       │                            │       │           │ implementation challenges │                            │
# │       │                            │       │           │ and codebase              │                            │
# │       │                            │       │           │ considerations            │                            │
# │       │                            │       │           │ 3. Market expert provided │                            │
# │       │                            │       │           │ crucial user behavior     │                            │
# │       │                            │       │           │ data and competitive      │                            │
# │       │                            │       │           │ context                   │                            │
# │       │                            │       │           │ 4. Risk analyst           │                            │
# │       │                            │       │           │ synthesized all           │                            │
# │       │                            │       │           │ perspectives into a       │                            │
# │       │                            │       │           │ balanced final            │                            │
# │       │                            │       │           │ recommendation            │                            │
# │       │                            │       │           │                           │                            │
# │       │                            │       │           │ The trajectory maintains  │                            │
# │       │                            │       │           │ correct dependencies      │                            │
# │       │                            │       │           │ between nodes with        │                            │
# │       │                            │       │           │ finance_expert as the     │                            │
# │       │                            │       │           │ entry point, followed by  │                            │
# │       │                            │       │           │ parallel evaluation from  │                            │
# │       │                            │       │           │ tech_expert and           │                            │
# │       │                            │       │           │ market_expert, and        │                            │
# │       │                            │       │           │ concludes with the        │                            │
# │       │                            │       │           │ risk_analyst integrating  │                            │
# │       │                            │       │           │ all inputs.               │                            │
# │       │                            │       │           │                           │                            │
# │       │                            │       │           │ The execution is          │                            │
# │       │                            │       │           │ efficient with no         │                            │
# │       │                            │       │           │ redundant steps, and the  │                            │
# │       │                            │       │           │ collaboration between     │                            │
# │       │                            │       │           │ experts produces a        │                            │
# │       │                            │       │           │ comprehensive analysis    │                            │
# │       │                            │       │           │ covering financial,       │                            │
# │       │                            │       │           │ technical, market, and    │                            │
# │       │                            │       │           │ risk dimensions. The      │                            │
# │       │                            │       │           │ final output provides a   │                            │
# │       │                            │       │           │ nuanced recommendation    │                            │
# │       │                            │       │           │ that balances immediate   │                            │
# │       │                            │       │           │ needs with long-term      │                            │
# │       │                            │       │           │ technical considerations. │                            │
# │       │                            │       │           │                           │                            │
# │       │                            │       │           │ According to the rubric,  │                            │
# │       │                            │       │           │ this trajectory meets all │                            │
# │       │                            │       │           │ the criteria for a "Very  │                            │
# │       │                            │       │           │ Good" (4/5) score: all    │                            │
# │       │                            │       │           │ required steps are        │                            │
# │       │                            │       │           │ present, correct order is │                            │
# │       │                            │       │           │ maintained, execution is  │                            │
# │       │                            │       │           │ efficient, and proper     │                            │
# │       │                            │       │           │ expert collaboration is   │                            │
# │       │                            │       │           │ demonstrated.             │                            │
# ├───────┼────────────────────────────┼───────┼───────────┼───────────────────────────┼────────────────────────────┤
# │ ▼ 2   │ Incorrect Decision Path -  │ 0.90  │ ✅        │ The trajectory shows an   │ Should we acquire a        │
# │       │ Missing Critical Analysis  │       │           │ excellent execution path  │ competitor for $5M?        │
# │       │                            │       │           │ for analyzing a potential │                            │
# │       │                            │       │           │ $5M competitor            │                            │
# │       │                            │       │           │ acquisition. The sequence │                            │
# │       │                            │       │           │ begins appropriately with │                            │
# │       │                            │       │           │ the 'finance_expert' who  │                            │
# │       │                            │       │           │ provides fundamental      │                            │
# │       │                            │       │           │ financial considerations  │                            │
# │       │                            │       │           │ and due diligence         │                            │
# │       │                            │       │           │ requirements. This        │                            │
# │       │                            │       │           │ correctly establishes the │                            │
# │       │                            │       │           │ financial framework       │                            │
# │       │                            │       │           │ before moving to market   │                            │
# │       │                            │       │           │ considerations. The       │                            │
# │       │                            │       │           │ 'market_expert' then      │                            │
# │       │                            │       │           │ analyzes competitive      │                            │
# │       │                            │       │           │ landscape factors and     │                            │
# │       │                            │       │           │ market positioning        │                            │
# │       │                            │       │           │ benefits, building on the │                            │
# │       │                            │       │           │ financial foundation. The │                            │
# │       │                            │       │           │ 'tech_expert'             │                            │
# │       │                            │       │           │ appropriately follows by  │                            │
# │       │                            │       │           │ examining technical       │                            │
# │       │                            │       │           │ integration challenges    │                            │
# │       │                            │       │           │ and compatibility issues, │                            │
# │       │                            │       │           │ which are critical        │                            │
# │       │                            │       │           │ considerations in         │                            │
# │       │                            │       │           │ acquisitions. Finally,    │                            │
# │       │                            │       │           │ the 'risk_analyst'        │                            │
# │       │                            │       │           │ synthesizes all previous  │                            │
# │       │                            │       │           │ inputs to provide a       │                            │
# │       │                            │       │           │ comprehensive risk        │                            │
# │       │                            │       │           │ assessment and final      │                            │
# │       │                            │       │           │ recommendation. This      │                            │
# │       │                            │       │           │ represents an optimal     │                            │
# │       │                            │       │           │ execution path with       │                            │
# │       │                            │       │           │ perfect ordering: from    │                            │
# │       │                            │       │           │ financial fundamentals →  │                            │
# │       │                            │       │           │ market considerations →   │                            │
# │       │                            │       │           │ technical challenges →    │                            │
# │       │                            │       │           │ culminating in risk       │                            │
# │       │                            │       │           │ analysis and              │                            │
# │       │                            │       │           │ recommendations. The flow │                            │
# │       │                            │       │           │ demonstrates proper       │                            │
# │       │                            │       │           │ expert collaboration with │                            │
# │       │                            │       │           │ each specialist building  │                            │
# │       │                            │       │           │ on previous insights.     │                            │
# │       │                            │       │           │ There are no unnecessary  │                            │
# │       │                            │       │           │ steps or inefficiencies   │                            │
# │       │                            │       │           │ in the trajectory. The    │                            │
# │       │                            │       │           │ comprehensive output      │                            │
# │       │                            │       │           │ demonstrates thorough     │                            │
# │       │                            │       │           │ consideration of          │                            │
# │       │                            │       │           │ financial, market,        │                            │
# │       │                            │       │           │ technical, and risk       │                            │
# │       │                            │       │           │ factors, resulting in a   │                            │
# │       │                            │       │           │ balanced recommendation   │                            │
# │       │                            │       │           │ that acknowledges both    │                            │
# │       │                            │       │           │ opportunities and         │                            │
# │       │                            │       │           │ challenges of the         │                            │
# │       │                            │       │           │ acquisition.              │                            │
# └───────┴────────────────────────────┴───────┴───────────┴───────────────────────────┴────────────────────────────┘
# Enter the test case number to expand/collapse it, o to expand all, and c to collapse all (q to quit).:

# %% [markdown]
# ### Visualizing Trajectory Metrics
#
# Let's create a summary visualization comparing all three trajectory scenarios.

# %%
# Compile trajectory metrics for comparison
trajectories_summary = [
    {
        "scenario": "Optimal",
        "expected": expected_optimal_trajectory,
        "actual": optimal_trajectory,
        "exact_match": exact_match_scorer(expected_optimal_trajectory, optimal_trajectory),
        "in_order_match": in_order_match_scorer(expected_optimal_trajectory, optimal_trajectory),
        "any_order_match": any_order_match_scorer(expected_optimal_trajectory, optimal_trajectory),
        "efficiency": len(expected_optimal_trajectory) / len(optimal_trajectory) if optimal_trajectory else 0
    },
    {
        "scenario": "Suboptimal",
        "expected": expected_suboptimal_trajectory,
        "actual": simulated_suboptimal_trajectory,
        "exact_match": exact_match_scorer(expected_suboptimal_trajectory, simulated_suboptimal_trajectory),
        "in_order_match": in_order_match_scorer(expected_suboptimal_trajectory, simulated_suboptimal_trajectory),
        "any_order_match": any_order_match_scorer(expected_suboptimal_trajectory, simulated_suboptimal_trajectory),
        "efficiency": len(expected_suboptimal_trajectory) / len(simulated_suboptimal_trajectory)
    },
    {
        "scenario": "Incorrect",
        "expected": expected_incorrect_trajectory,
        "actual": simulated_incorrect_trajectory,
        "exact_match": exact_match_scorer(expected_incorrect_trajectory, simulated_incorrect_trajectory),
        "in_order_match": in_order_match_scorer(expected_incorrect_trajectory, simulated_incorrect_trajectory),
        "any_order_match": any_order_match_scorer(expected_incorrect_trajectory, simulated_incorrect_trajectory),
        "efficiency": len([s for s in simulated_incorrect_trajectory if s in expected_incorrect_trajectory]) / len(expected_incorrect_trajectory)
    }
]

# Create comparison table
comparison_md = """
## Trajectory Comparison Summary

| Scenario | Exact Match | In-Order Match | Any-Order Match | Efficiency |
|:---------|:------------|:---------------|:----------------|:-----------|
"""

for t in trajectories_summary:
    comparison_md += f"| {t['scenario']} | {t['exact_match']:.2f} | {t['in_order_match']:.2f} | {t['any_order_match']:.2f} | {t['efficiency']:.2%} |\n"

comparison_md += """

### Key Insights

**Optimal Trajectory:**
- Perfect scores across all metrics (1.00)
- 100% efficiency - no wasted steps
- Represents ideal execution pattern

**Suboptimal Trajectory:**
- Exact match fails due to extra steps
- In-order and any-order matches are perfect (1.00)
- 67% efficiency due to redundant calls
- Correct but inefficient execution

**Incorrect Trajectory:**
- All metrics show significant degradation
- Only 50% of expected steps present
- 50% efficiency - missing critical analyses
- Represents problematic execution requiring fixes

### Choosing the Right Scorer

**Use Exact Match when:**
- Strict compliance is required (medical, financial)
- Regulatory requirements demand specific steps
- Safety-critical applications

**Use In-Order Match when:**
- Sequence matters but flexibility is acceptable
- Extra logging or validation steps are okay
- Focus is on correctness over efficiency

**Use Any-Order Match when:**
- Steps are independent
- Order doesn't affect outcome
- Parallel execution is possible
"""

display(Markdown(comparison_md))
# Out:
# ## Trajectory Comparison Summary
#
# | Scenario | Exact Match | In-Order Match | Any-Order Match | Efficiency |
# |:---------|:------------|:---------------|:----------------|:-----------|
# | Optimal | 1.00 | 1.00 | 1.00 | 100.00% |
# | Suboptimal | 0.00 | 1.00 | 1.00 | 66.67% |
# | Incorrect | 0.00 | 0.50 | 0.75 | 75.00% |
#
#
# ### Key Insights
#
# **Optimal Trajectory:**
# - Perfect scores across all metrics (1.00)
# - 100% efficiency - no wasted steps
# - Represents ideal execution pattern
#
# **Suboptimal Trajectory:**
# - Exact match fails due to extra steps
# - In-order and any-order matches are perfect (1.00)
# - 67% efficiency due to redundant calls
# - Correct but inefficient execution
#
# **Incorrect Trajectory:**
# - All metrics show significant degradation
# - Only 50% of expected steps present
# - 50% efficiency - missing critical analyses
# - Represents problematic execution requiring fixes
#
# ### Choosing the Right Scorer
#
# **Use Exact Match when:**
# - Strict compliance is required (medical, financial)
# - Regulatory requirements demand specific steps
# - Safety-critical applications
#
# **Use In-Order Match when:**
# - Sequence matters but flexibility is acceptable
# - Extra logging or validation steps are okay
# - Focus is on correctness over efficiency
#
# **Use Any-Order Match when:**
# - Steps are independent
# - Order doesn't affect outcome
# - Parallel execution is possible

# %% [markdown]
# ### Best Practices for Trajectory Evaluation
#
# #### When to Evaluate Trajectories
#
# | Situation | Why |
# |:----------|:----|
# | Debugging unexpected behavior | Identify where agent deviates |
# | Optimizing performance | Find inefficiencies and redundant steps |
# | Ensuring compliance | Validate required workflow steps |
# | Comparing implementations | Benchmark different agent versions |
#
# #### Choosing Evaluation Criteria
#
# | Factor | Consideration |
# |:-------|:--------------|
# | Domain requirements | Some domains require strict order (medical, legal) |
# | Efficiency goals | Balance correctness with performance |
# | Cost constraints | Redundant steps increase API costs |
#
# #### Combining Trajectory and Output Evaluation
#
# Evaluate both trajectory (HOW) and output (WHAT) for complete visibility:
# ```python
# combined_score = (trajectory_score * 0.4) + (output_score * 0.6)
# ```
#
# #### Production Monitoring
#
# Monitor: trajectory lengths, tool usage patterns, execution times, failure points.

# %% [markdown]
# ### Summary
#
# You've successfully learned how to evaluate agent trajectories using Strands Evals. You now understand:
#
# - **What trajectories are**: Sequences of tool calls and reasoning steps agents use to solve tasks
# - **Why trajectory evaluation matters**: Understanding HOW agents think, not just WHAT they produce
# - **Trajectory hierarchy**: Session → Trace → Spans structure in Strands
# - **Three trajectory patterns**:
#   - Optimal: Correct tools in correct order
#   - Suboptimal: Extra or redundant steps
#   - Incorrect: Wrong tools or wrong order
# - **Scoring functions**:
#   - exact_match_scorer: Strict sequence matching
#   - in_order_match_scorer: Allows extra steps
#   - any_order_match_scorer: Ignores order
# - **TrajectoryEvaluator**: LLM-based trajectory assessment with custom rubrics
# - **Best practices**: When and how to evaluate trajectories effectively
#
# Trajectory evaluation is essential for understanding agent behavior, optimizing performance, and ensuring reliable execution. By evaluating both the process (trajectory) and the result (output), you gain complete visibility into agent systems.
