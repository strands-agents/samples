# %% [markdown]
# ## AB Testing Models - Evaluating Agent Performance
#
# Learn how to systematically evaluate multiple agent variants using different language models. This tutorial shows you how to run parallel evaluations, compare performance metrics, analyze cost-performance trade-offs, and generate data-driven model selection recommendations.
#
# ### What You'll Learn
# - Load agent configurations from Part 1 and recreate agents
# - Create diverse evaluation datasets from TauBench scenarios
# - Run systematic evaluations on multiple agent variants
# - Use five built-in evaluators for comprehensive assessment
# - Compare evaluation scores side-by-side across models
# - Calculate statistical measures (mean, standard deviation)
# - Analyze cost-performance trade-offs
# - Generate actionable model selection recommendations
#
# ### Tutorial Details
#
# | Information         | Details                                                                       |
# |:--------------------|:------------------------------------------------------------------------------|
# | Tutorial type       | Advanced - Systematic model evaluation and comparison                         |
# | Tutorial components | Multi-model evaluation, statistical analysis, cost-performance optimization   |
# | Tutorial vertical   | Agent Evaluation                                                              |
# | Example complexity  | Advanced                                                                      |
# | SDK used            | Strands Agents, Strands Evals                                                 |

# %% [markdown]
# ### Understanding A/B Testing Evaluation
#
# Systematic evaluation answers: Which model produces highest quality responses? Best completes goals? Selects tools most accurately? Provides best cost-performance ratio?
#
# #### Five Dimensions of Evaluation
#
# | Evaluator | Purpose |
# |:----------|:--------|
# | OutputEvaluator | Measures response quality, correctness, completeness |
# | HelpfulnessEvaluator | Assesses practical value, clarity, actionability |
# | GoalSuccessRateEvaluator | Tracks binary success/failure for task completion |
# | ToolSelectionAccuracyEvaluator | Validates appropriate tool choices |
# | ToolParameterAccuracyEvaluator | Checks parameter correctness and formatting |
#
# #### Evaluation Methodology
#
# | Requirement | Description |
# |:------------|:------------|
# | Same test dataset | All models tested on identical queries |
# | Same evaluation criteria | Consistent scoring across variants |
# | Multiple test cases | Statistical validity through volume |
#
# **Analysis Flow**: Run agents → Collect scores → Calculate statistics → Compare side-by-side → Factor cost → Generate recommendations

# %%
import os

# %% [markdown]
# ### Environment Setup
#
# Configure AWS region and prepare for multi-model evaluation.

# %%
import boto3

# AWS Configuration
session = boto3.Session()
AWS_REGION = session.region_name or 'us-east-1'

# %% [markdown]
# ### Setup and Imports
#
# Import all necessary libraries for evaluation and statistical analysis.

# %%
# Standard imports
import sys
import os
import json
import logging
from typing import Dict, List, Any
import statistics
from collections import defaultdict

# Add paths for airline tools (local data directory)
sys.path.append('./data/ma-bench/')
sys.path.append('./data/tau-bench/')

# Strands imports
from strands import Agent
from strands.models import BedrockModel

# Strands Evals imports
from strands_evals import Experiment, Case
from strands_evals.evaluators import (
    OutputEvaluator,
    HelpfulnessEvaluator,
    GoalSuccessRateEvaluator,
    ToolSelectionAccuracyEvaluator,
    ToolParameterAccuracyEvaluator
)

# Display utilities
from IPython.display import Markdown, display

# Disable verbose logging
logging.basicConfig(level=logging.CRITICAL)
for logger_name in ["strands", "graph", "event_loop", "registry", "sliding_window_conversation_manager", "bedrock", "streaming"]:
    logging.getLogger(logger_name).setLevel(logging.CRITICAL)

# Bypass tool consent
os.environ["BYPASS_TOOL_CONSENT"] = "true"

# %% [markdown]
# ### Load Agent Configurations
#
# Load the agent configurations saved in Part 1 (Tutorial 07a).

# %%
# Load configuration from Part 1
config_path = "./agent_configs.json"

with open(config_path, "r") as f:
    config = json.load(f)

print("Loaded agent configurations:")
print(f"  Models: {len(config['models'])}")
print(f"  Dataset path: {config['dataset_path']}")
print(f"  Tools: {config['num_tools']}")
print("\nModel variants:")
for key, model_info in config['models'].items():
    print(f"  {model_info['name']}: {model_info['model_id']}")
# Out:
# Loaded agent configurations:
#   Models: 3
#   Dataset path: ./data/tau-bench/tau_bench/envs/airline/tasks_singleturn.json
#   Tools: 14
#
# Model variants:
#   Claude Haiku: us.anthropic.claude-3-5-haiku-20241022-v1:0
#   Claude Sonnet: us.anthropic.claude-3-7-sonnet-20250219-v1:0
#   Nova Lite: us.amazon.nova-lite-v1:0

# %% [markdown]
# ### Import Airline Domain Tools
#
# Recreate the airline tool environment for all three agent variants.

# %%
# Import all 14 airline tools
from mabench.environments.airline.tools.book_reservation import book_reservation
from mabench.environments.airline.tools.calculate import calculate
from mabench.environments.airline.tools.cancel_reservation import cancel_reservation
from mabench.environments.airline.tools.get_reservation_details import get_reservation_details
from mabench.environments.airline.tools.get_user_details import get_user_details
from mabench.environments.airline.tools.list_all_airports import list_all_airports
from mabench.environments.airline.tools.search_direct_flight import search_direct_flight
from mabench.environments.airline.tools.search_onestop_flight import search_onestop_flight
from mabench.environments.airline.tools.send_certificate import send_certificate
from mabench.environments.airline.tools.think import think
from mabench.environments.airline.tools.transfer_to_human_agents import transfer_to_human_agents
from mabench.environments.airline.tools.update_reservation_baggages import update_reservation_baggages
from mabench.environments.airline.tools.update_reservation_flights import update_reservation_flights
from mabench.environments.airline.tools.update_reservation_passengers import update_reservation_passengers

# Import airline policy
from tau_bench.envs.airline.wiki import WIKI

# Define tools list
AIRLINE_TOOLS = [
    book_reservation,
    calculate,
    cancel_reservation,
    get_reservation_details,
    get_user_details,
    list_all_airports,
    search_direct_flight,
    search_onestop_flight,
    send_certificate,
    think,
    transfer_to_human_agents,
    update_reservation_baggages,
    update_reservation_flights,
    update_reservation_passengers,
]

# Create system prompt
SYSTEM_PROMPT_TEMPLATE = """
You are a helpful assistant for a travel website. Help the user answer any questions.

<instructions>
- Remember to check if the airport city is in the state mentioned by the user. For example, Houston is in Texas.
- Infer about the U.S. state in which the airport city resides. For example, Houston is in Texas.
- You should not use made-up or placeholder arguments.
</instructions>

<policy>
{policy}
</policy>
"""

AIRLINE_SYSTEM_PROMPT = SYSTEM_PROMPT_TEMPLATE.replace("{policy}", WIKI)

print(f"Imported {len(AIRLINE_TOOLS)} airline tools")
print(f"System prompt created ({len(AIRLINE_SYSTEM_PROMPT)} characters)")
# Out:
# Imported 14 airline tools
# System prompt created (6561 characters)

# %% [markdown]
# ### Recreate All Three Agent Variants
#
# Build the three agent variants (Haiku, Sonnet, Nova Lite) for evaluation.

# %%
# Create BedrockModels for each variant
model_haiku = BedrockModel(
    region_name=AWS_REGION,
    model_id=config['models']['haiku']['model_id']
)

model_sonnet = BedrockModel(
    region_name=AWS_REGION,
    model_id=config['models']['sonnet']['model_id']
)

model_nova_lite = BedrockModel(
    region_name=AWS_REGION,
    model_id=config['models']['nova_lite']['model_id']
)

# Create agents
agent_haiku = Agent(
    name="airline_assistant_haiku",
    model=model_haiku,
    tools=AIRLINE_TOOLS,
    system_prompt=AIRLINE_SYSTEM_PROMPT
)

agent_sonnet = Agent(
    name="airline_assistant_sonnet",
    model=model_sonnet,
    tools=AIRLINE_TOOLS,
    system_prompt=AIRLINE_SYSTEM_PROMPT
)

agent_nova_lite = Agent(
    name="airline_assistant_nova_lite",
    model=model_nova_lite,
    tools=AIRLINE_TOOLS,
    system_prompt=AIRLINE_SYSTEM_PROMPT
)

# Store in dictionary for easy iteration
agents = {
    "haiku": {"agent": agent_haiku, "name": "Claude Haiku"},
    "sonnet": {"agent": agent_sonnet, "name": "Claude Sonnet"},
    "nova_lite": {"agent": agent_nova_lite, "name": "Nova Lite"}
}

print("All three agent variants created:")
for key, info in agents.items():
    print(f"  {info['name']}: Ready")
# Out:
# All three agent variants created:
#   Claude Haiku: Ready
#   Claude Sonnet: Ready
#   Nova Lite: Ready

# %% [markdown]
# ### Load TauBench Dataset
#
# Load the full TauBench airline dataset and select diverse test cases for evaluation.

# %%
# Load TauBench dataset
dataset_path = config['dataset_path']

with open(dataset_path, "r") as file:
    all_tasks = json.load(file)

print(f"Loaded {len(all_tasks)} total scenarios from TauBench")
print("\nDataset includes:")
print("  - Flight searches and bookings")
print("  - Reservation modifications")
print("  - Cancellations and refunds")
print("  - Customer service inquiries")
print("  - Policy-based decisions")
# Out:
# Loaded 50 total scenarios from TauBench
#
# Dataset includes:
#   - Flight searches and bookings
#   - Reservation modifications
#   - Cancellations and refunds
#   - Customer service inquiries
#   - Policy-based decisions

# %% [markdown]
# ### Select Diverse Test Cases
#
# Choose 12 diverse test cases that represent different complexity levels and scenario types.

# %%
# Select diverse test cases (indices chosen for variety)
selected_indices = [0, 1] #, 2, 4, 10, 15, 20, 25, 30, 35, 40, 45]
selected_tasks = [all_tasks[i] for i in selected_indices]

print(f"Selected {len(selected_tasks)} diverse test cases:")
print("\nTest Case Overview:")
for i, task in enumerate(selected_tasks, 1):
    question_preview = task['question'].replace('\n', ' ') + "..."
    print(f"  {i}. {question_preview}")
# Out:
# Selected 2 diverse test cases:
#
# Test Case Overview:
#   1.  My user id is mia_li_3668. I want to fly from New York to Seattle on May 20 (one way). I do not want to fly before 11am EST. I want to fly in economy. I prefer direct flights but one stopover is also fine. If there are multiple options, I prefer the one with the lowest price. I have 3 baggages. I do not want insurance. I want to use my two certificates to pay. If only one certificate can be used, I prefer using the larger one, and pay the rest with my 7447 card. ...
#   2.  My user id is olivia_gonzalez_2305. I currently reside in Newark. I have a reservation for a half-day trip to Texas, but I do not remember the reservation id. I want to change my return flight from Texas to Newark to a later time on the same day, or if not possible, the earliest flight the next day. My current return flight departs at 3pm from Texas. I only accept flights from EWR, not JFK. If my basic economy ticket cannot be modified, I am willing to cancel the trip using the travel insurance as I feel unwell, and I can book the flight again later. ...

# %% [markdown]
# ### Create Evaluation Dataset
#
# Build Strands Evals dataset with test cases and five evaluators.

# %%
# Create Case objects for evaluation
test_cases = []
for i, task in enumerate(selected_tasks):
    # Use 'question' if available, otherwise fall back to 'instruction'
    user_query = task.get('question', task.get('instruction', ''))
    case = Case(
        name=f"Scenario_{i+1}_{task['user_id']}",
        input=user_query,  # ✅ Works for both schemas
        expected_output="A helpful, accurate response that addresses the user's airline service request."
    )
    test_cases.append(case)

# Create separate experiments for each evaluator
evaluator_list = [
    ("OutputEvaluator", OutputEvaluator(rubric="The output should provide a helpful, accurate response to the airline service request.")),
    ("HelpfulnessEvaluator", HelpfulnessEvaluator()),
    ("GoalSuccessRateEvaluator", GoalSuccessRateEvaluator()),
    ("ToolSelectionAccuracyEvaluator", ToolSelectionAccuracyEvaluator()),
    ("ToolParameterAccuracyEvaluator", ToolParameterAccuracyEvaluator())
]

dataset_output = Experiment(
    cases=test_cases,
    evaluator=evaluator_list[0][1]
)

dataset_helpfulness = Experiment(
    cases=test_cases,
    evaluator=evaluator_list[1][1]
)

dataset_goal = Experiment(
    cases=test_cases,
    evaluator=evaluator_list[2][1]
)

dataset_tool_selection = Experiment(
    cases=test_cases,
    evaluator=evaluator_list[3][1]
)

dataset_tool_parameter = Experiment(
    cases=test_cases,
    evaluator=evaluator_list[4][1]
)

print(f"Evaluation experiments created:")
print(f"  Test cases: {len(test_cases)}")
print(f"  Evaluators: {len(evaluator_list)} (one experiment per evaluator)")
print("\nEvaluator types:")
for evaluator_name, _ in evaluator_list:
    print(f"  - {evaluator_name}")
# Out:
# Evaluation experiments created:
#   Test cases: 2
#   Evaluators: 5 (one experiment per evaluator)
#
# Evaluator types:
#   - OutputEvaluator
#   - HelpfulnessEvaluator
#   - GoalSuccessRateEvaluator
#   - ToolSelectionAccuracyEvaluator
#   - ToolParameterAccuracyEvaluator

# %% [markdown]
# ### Run Evaluation: Claude Haiku
#
# Evaluate the Claude Haiku agent variant on all test cases.

# %%
# Define agent task function for Haiku
def agent_task_haiku(case: Case) -> str:
    """Execute Haiku agent with the given case input."""
    agent_haiku.messages = []
    response = agent_haiku(case.input)
    return str(response)

# Run evaluations for all 5 evaluators
print("[EVALUATING HAIKU]")
print("Running evaluation on Claude Haiku agent...")

print("  [1/5] OutputEvaluator...")
report_haiku_output = dataset_output.run_evaluations(agent_task_haiku)

print("  [2/5] HelpfulnessEvaluator...")
report_haiku_helpfulness = dataset_helpfulness.run_evaluations(agent_task_haiku)

print("  [3/5] GoalSuccessRateEvaluator...")
report_haiku_goal = dataset_goal.run_evaluations(agent_task_haiku)

print("  [4/5] ToolSelectionAccuracyEvaluator...")
report_haiku_tool_selection = dataset_tool_selection.run_evaluations(agent_task_haiku)

print("  [5/5] ToolParameterAccuracyEvaluator...")
report_haiku_tool_parameter = dataset_tool_parameter.run_evaluations(agent_task_haiku)

print("Haiku evaluation complete (5 evaluation rounds)")
# Out:
# [EVALUATING HAIKU]
# Running evaluation on Claude Haiku agent...
#   [1/5] OutputEvaluator...
# I'll help you book your flight from New York to Seattle. First, I'll search for available direct and one-stop flights on your preferred date.
#
# Let me first check the airport codes for New York and Seattle:
# Tool #1: list_all_airports
# I'll search for direct flights first from JFK (New York) to SEA (Seattle):
# Tool #2: search_direct_flight
# Now, I'll check one-stop flights:
# Tool #3: search_onestop_flight
# Based on your requirements, here are the best options:
#
# Direct Flights:
# 1. HAT069: Departs 06:00 AM EST, Economy price: $121
# 2. HAT083: Departs 01:00 AM EST (does not meet your 11 AM requirement)
#
# One-Stop Flights:
# 1. JFK-ATL-SEA route with total Economy price: $244 (HAT057 + HAT039)
#    First leg departs at 07:00 AM EST, arrives at SEA at 03:00 AM next day
#
# I recommend the direct HAT069 flight as it meets your timing preferences and is a direct flight.
#
# Now, I'll retrieve your user details to check your certificates:
# Tool #4: get_user_details
# You have two certificates:
# 1. Certificate 4856383: $100
# 2. Certificate 7504069: $250
#
# The flight cost is $121, so I recommend using the $250 certificate and paying the remaining $21 with your 7447 card.
#
# Would you like me to proceed with booking the HAT069 flight on May 20, 2024, from JFK to SEA in economy class with 3 baggages, using the $250 certificate and your credit card for the remaining balance? Please confirm with a "yes" or provide any modifications.I'll help you with your request. Let me break this down step by step:
#
# 1. First, I'll retrieve your user details to confirm your information:
# Tool #5: get_user_details
# I see you have multiple reservations. However, I'll need the specific reservation ID for the Texas trip to help you modify or cancel it. Since you mentioned you don't remember the ID, I recommend checking each of your existing reservations:
# Tool #6: get_reservation_details
# Great! I found your reservation to Texas (IAH is Houston, which is in Texas). The details are:
# - Reservation ID: Z7GOZK
# - Current return flight: HAT207 on 2024-05-28 at 3 PM
# - Cabin: Basic Economy
# - Insurance: Yes
#
# Now, I'll search for alternative flights from Houston (IAH) to Newark (EWR) on the same day:
# Tool #7: search_direct_flight
# You're in luck! There are multiple flight options:
# 1. HAT149 at 8:00 AM (earlier option)
# 2. HAT195 at 2:00 PM (close to your current time)
# 3. HAT207 at 3:00 PM (your current flight)
#
# However, since you're on a basic economy ticket, you cannot modify the flight. As per our policy, you mentioned you want to cancel using travel insurance due to not feeling well.
#
# Would you like me to proceed with cancelling your reservation using the travel insurance? I'll need your confirmation. Please respond with "Yes, cancel the reservation" if you want me to proceed with cancellation.
#
# Important notes:
# - You have travel insurance on this reservation
# - You can get a full refund due to health reasons
# - The cancellation will refund to your original payment method (gift card) within 5-7 business days
#
# Shall I proceed with the cancellation?  [2/5] HelpfulnessEvaluator...
# I'll help you book your flight from New York to Seattle. Let me break this down step by step:
#
# First, I'll check the available direct flights:
# Tool #8: search_direct_flight
# Since you don't want to fly before 11am EST, I'll check one-stop flights for additional options:
# Tool #9: search_onestop_flight
# Let me first check your user details to see your certificates:
# Tool #10: get_user_details
# Based on the search results and your requirements:
# 1. Direct Flight Option: HAT069 at 6:00 AM (which doesn't meet your time preference)
# 2. Direct Flight Option: HAT083 at 1:00 AM (also doesn't meet your time preference)
#
# One-stop flight options include various combinations, but the most economical seems to be:
# - First Leg: HAT136 (JFK to ATL) at 7:00 PM
# - Second Leg: HAT039 (ATL to SEA) at 10:00 PM
#
# You have two certificates:
# - Certificate 1: $100
# - Certificate 2: $250
#
# The total flight cost in economy is $141 + $103 = $244
#
# Let me confirm the details with you:
# 1. Would you like to book the one-stop flight (HAT136 + HAT039) departing at 7:00 PM from JFK?
# 2. I recommend using the $250 certificate first, then the remaining $6 on your credit card 7447.
# 3. You mentioned 3 baggages and no insurance.
# 4. Do you want to provide the passenger details?
#
# Please confirm these details, and I'll proceed with the booking.Let me help you with your request. First, I'll retrieve your reservation details to find the reservation ID.
# Tool #11: get_user_details
# I see you have three reservations. I'll check the details of each to find the one related to your Texas trip:
# Tool #12: get_reservation_details
#
# Tool #13: get_reservation_details
#
# Tool #14: get_reservation_details
# I found your reservation to Texas (IAH - Houston) with the reservation ID Z7GOZK. I notice a few things:
# 1. It's a basic economy ticket
# 2. You have travel insurance
# 3. The current return flight (HAT207) is on 2024-05-28 at 3 PM from IAH to EWR
#
# Since you mentioned you want to change the return flight to a later time on the same day or the next day, I'll search for available flights:
# Tool #15: search_direct_flight
#
# Tool #16: search_direct_flight
# I understand your situation. Here are your options:
#
# 1. For the same day (2024-05-28):
#    - HAT149 at 8:00 AM (early morning)
#    - HAT195 at 2:00 PM (an hour earlier than your current flight)
#    - HAT207 at 3:00 PM (your current flight)
#
# 2. For the next day (2024-05-29):
#    - HAT149 at 8:00 AM (earliest flight)
#    - HAT195 at 2:00 PM
#    - HAT207 at 3:00 PM
#
# However, since this is a basic economy ticket, modification is typically not allowed. Given that you have travel insurance and are feeling unwell, I recommend we proceed with cancelling the reservation and then rebooking later.
#
# Would you like me to:
# 1. Cancel the entire reservation (Z7GOZK) due to your health condition?
# 2. Explore other options?
#
# Please confirm your preference.  [3/5] GoalSuccessRateEvaluator...
# I'll help you book your flight from New York to Seattle. Let me break this down step by step:
#
# First, I'll check the available direct flights:
# Tool #17: search_direct_flight
# Now, I'll check one-stop flights:
# Tool #18: search_onestop_flight
# Let me help you choose the best flight:
#
# 1. Direct Flights:
#    - HAT069 (06:00 AM EST) - Economy price: $121
#    - HAT083 (01:00 AM EST) - Economy price: $100
#
# 2. One-Stop Flights (multiple options with similar pricing):
#    - JFK-ATL-SEA with various first leg timings, final leg at 22:00 PM
#    - Lowest economy price for one-stop: $103 (first flight HAT057, second flight HAT039)
#
# Since you specified not wanting to fly before 11am EST, the HAT069 direct flight at 6:00 AM is not suitable. The HAT083 direct flight at 1:00 AM is also too early.
#
# The one-stop flight with the lowest price is the HAT057 to ATL at 7:00 AM, then HAT039 to SEA at 22:00 PM. While this doesn't meet your 11 AM preference, it's the most economical option.
#
# Now, I'll check your user details to confirm your certificates:
# Tool #19: get_user_details
# Great! You have two certificates:
# 1. certificate_4856383 with $100
# 2. certificate_7504069 with $250
#
# The flight price is $121, so I recommend using the $250 certificate and the remaining $121 - $100 = $21 on your 7447 credit card.
#
# Would you like me to proceed with booking the one-stop flight (HAT057 and HAT039) on May 20, 2024, in economy class, using the $250 certificate and your 7447 credit card for the remaining amount? I'll need your confirmation and passenger details to complete the booking.I'll help you with this. Let me break this down step by step:
#
# 1. First, I'll retrieve your user details to confirm your information.
# Tool #20: get_user_details
# I see you have multiple reservation IDs. Unfortunately, I cannot determine which one is specifically for your Texas trip. I'll need you to provide the specific reservation ID for me to help you modify or cancel it.
#
# Could you please:
# 1. Confirm the exact reservation ID for your Texas trip? You can find this in a previous confirmation email or communication about the booking.
# 2. Confirm which Texas airport you're flying from (e.g., DFW for Dallas/Fort Worth, IAH for Houston)
# 3. Confirm the specific date of your return flight
#
# Before I can proceed with modifying or canceling the reservation, I need to verify:
# - The reservation ID
# - Your specific travel details
# - Confirm your willingness to proceed with changes or cancellation
#
# Important notes based on your situation:
# - You mentioned a basic economy ticket, which typically cannot be modified
# - You have travel insurance and are feeling unwell, which would allow for cancellation
# - You specifically want to depart from EWR (Newark)
#
# Could you please provide me with the missing details so I can assist you effectively?  [4/5] ToolSelectionAccuracyEvaluator...
# I'll help you book your flight from New York to Seattle. Let me break this down step by step:
#
# First, I'll check the available direct flights:
# Tool #21: search_direct_flight
# Now, I'll check one-stop flights:
# Tool #22: search_onestop_flight
# Let me get the user's details to check available certificates:
# Tool #23: get_user_details
# Based on the search results and your requirements, here are the observations:
# 1. Direct Flights:
#    - HAT069 departs at 06:00 EST (before your preferred time)
#    - HAT083 departs at 01:00 EST (before your preferred time)
#
# 2. One-stop Flights:
#    - Best economy price is the route with HAT057 (JFK to ATL) and HAT039 (ATL to SEA)
#      * First leg departs at 07:00 EST (before your preferred time)
#
# 3. Certificates:
#    - You have two certificates:
#      * Certificate 1 (ID: certificate_4856383): $100
#      * Certificate 2 (ID: certificate_7504069): $250
#
# I notice that none of the flights meet your preference of departing after 11am EST. Would you like to:
# A) Choose an earlier flight despite the time constraint
# B) Look for flights on a different date
# C) Adjust your time preference
#
# Please confirm how you'd like to proceed. Once we select a flight, I'll help you book it using your preferred payment method (certificates and credit card).I'll help you with your request. Let me break this down step by step:
#
# 1. First, I'll retrieve your reservation details to find the reservation ID.
# Tool #24: get_user_details
# I see you have multiple reservations. I'll check the details of each to find the Texas trip:
# Tool #25: get_reservation_details
#
# Tool #26: get_reservation_details
#
# Tool #27: get_reservation_details
# I noticed that the first reservation (Z7GOZK) involves a trip to Houston (IAH), which is in Texas. The return flight is currently scheduled for 2024-05-28 at 3 PM.
#
# Now, I'll search for alternative flights from IAH (Houston) to EWR (Newark) on the same day and the next day:
# Tool #28: search_direct_flight
#
# Tool #29: search_direct_flight
# I understand your situation. Since this is a basic economy ticket, modification is typically not allowed. However, you mentioned you have travel insurance and are feeling unwell, which would allow you to cancel the reservation.
#
# Here are the alternative flight options:
# On the same day (2024-05-28):
# 1. HAT149 at 8:00 AM
# 2. HAT195 at 2:00 PM
# 3. HAT207 at 3:00 PM (your current flight)
#
# On the next day (2024-05-29):
# 1. HAT149 at 8:00 AM (earliest flight)
# 2. HAT195 at 2:00 PM
# 3. HAT207 at 3:00 PM
#
# Would you like to:
# 1. Cancel the current reservation using your travel insurance due to not feeling well?
# 2. Discuss alternative flight options for rebooking?
#
# Please confirm your preference, and I'll be happy to assist you further.  [5/5] ToolParameterAccuracyEvaluator...
# I'll help you book your flight from New York to Seattle. Let me break this down step by step:
#
# First, I'll check the available direct flights:
# Tool #30: search_direct_flight
# I see two direct flights, but neither meets your preference of departing after 11am EST. Let me check one-stop flights:
# Tool #31: search_onestop_flight
# Now, I'll check the user details to confirm certificates:
# Tool #32: get_user_details
# Based on the search results and your requirements:
# 1. The one-stop flight with the lowest total price is:
#    - First leg: HAT136 (JFK to ATL) departing at 7:00 PM
#    - Second leg: HAT039 (ATL to SEA) departing at 10:00 PM
#
# 2. I see two certificates:
#    - Certificate 7504069: $250
#    - Certificate 4856383: $100
#
# I'll proceed with booking using the $250 certificate and the credit card ending in 7447 for the remaining balance.
#
# Let me confirm the details with you:
# - User ID: mia_li_3668
# - Origin: New York (JFK)
# - Destination: Seattle (SEA)
# - Date: May 20, 2024
# - Flight: One-stop (HAT136 and HAT039)
# - Cabin: Economy
# - Baggages: 3 total
# - Payment: $250 certificate and remaining balance on credit card 7447
# - Insurance: No
#
# Do you want me to proceed with booking this flight? Please confirm with a "yes".Let me help you with that. I'll break this down step by step.
#
# First, I'll retrieve your user details to confirm your information.
# Tool #33: get_user_details
# I see you have a few reservations. Since you mentioned you want to modify a return flight from Texas, I'll check the details of each reservation to find the relevant one.
#
# Let me retrieve the details for each reservation:
# Tool #34: get_reservation_details
#
# Tool #35: get_reservation_details
#
# Tool #36: get_reservation_details
# I notice that your reservation Z7GOZK is a trip from Newark (EWR) to Houston (IAH), which matches your description of a Texas trip. The return flight is currently at 3pm on 2024-05-28.
#
# Since you have basic economy and mentioned wanting to modify or cancel the flight, I'll explain the options:
#
# 1. Modification: Your basic economy ticket cannot be modified according to our policy.
#
# 2. Cancellation: You mentioned feeling unwell and having travel insurance, which allows you to cancel the trip.
#
# Would you like me to help you cancel this reservation using your travel insurance? If yes, I'll proceed with cancellation. If not, please let me know how you'd like to proceed.
#
# Just to confirm the details:
# - Reservation ID: Z7GOZK
# - Current Return Flight: From IAH to EWR on 2024-05-28 at 3pm
# - Cabin: Basic Economy
# - Insurance: Yes
#
# What would you like to do?Haiku evaluation complete (5 evaluation rounds)

# %% [markdown]
# #### Haiku Results
#
# Display evaluation results for Claude Haiku.

# %%
print("\n" + "=" * 80)
print("CLAUDE HAIKU RESULTS")
print("=" * 80)

print("\n[1/5] OUTPUT QUALITY")
print("-" * 80)
report_haiku_output.display()

print("\n[2/5] HELPFULNESS")
print("-" * 80)
report_haiku_helpfulness.display()

print("\n[3/5] GOAL SUCCESS RATE")
print("-" * 80)
report_haiku_goal.display()

print("\n[4/5] TOOL SELECTION ACCURACY")
print("-" * 80)
report_haiku_tool_selection.display()

print("\n[5/5] TOOL PARAMETER ACCURACY")
print("-" * 80)
report_haiku_tool_parameter.display()
# Out:
# ================================================================================
# CLAUDE HAIKU RESULTS
# ================================================================================
#
# [1/5] OUTPUT QUALITY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.70           Pass Rate: 1.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.70  │ ✅        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.70  │ ✅        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [2/5] HELPFULNESS
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [3/5] GOAL SUCCESS RATE
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [4/5] TOOL SELECTION ACCURACY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [5/5] TOOL PARAMETER ACCURACY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘

# %% [markdown]
# ### Run Evaluation: Claude Sonnet
#
# Evaluate the Claude Sonnet agent variant on all test cases.

# %%
# Define agent task function for Sonnet
def agent_task_sonnet(case: Case) -> str:
    """Execute Sonnet agent with the given case input."""
    agent_sonnet.messages = []
    response = agent_sonnet(case.input)
    return str(response)

# Run evaluations for all 5 evaluators
print("[EVALUATING SONNET]")
print("Running evaluation on Claude Sonnet agent...")

print("  [1/5] OutputEvaluator...")
report_sonnet_output = dataset_output.run_evaluations(agent_task_sonnet)

print("  [2/5] HelpfulnessEvaluator...")
report_sonnet_helpfulness = dataset_helpfulness.run_evaluations(agent_task_sonnet)

print("  [3/5] GoalSuccessRateEvaluator...")
report_sonnet_goal = dataset_goal.run_evaluations(agent_task_sonnet)

print("  [4/5] ToolSelectionAccuracyEvaluator...")
report_sonnet_tool_selection = dataset_tool_selection.run_evaluations(agent_task_sonnet)

print("  [5/5] ToolParameterAccuracyEvaluator...")
report_sonnet_tool_parameter = dataset_tool_parameter.run_evaluations(agent_task_sonnet)

print("Sonnet evaluation complete (5 evaluation rounds)")
# Out:
# [EVALUATING SONNET]
# Running evaluation on Claude Sonnet agent...
#   [1/5] OutputEvaluator...
# I'll help you find a flight from New York to Seattle on May 20th. Let me check your user details first and then search for flights meeting your criteria.
# Tool #1: get_user_details
# Now let me check what airports are available in New York to help with your flight search:
# Tool #2: list_all_airports
# I see that in New York, we have JFK airport, as well as LGA (LaGuardia) and EWR (Newark) airports. Let me search for direct flights from each of these airports to Seattle (SEA) on May 20th:
# Tool #3: search_direct_flight
#
# Tool #4: search_direct_flight
#
# Tool #5: search_direct_flight
# Now let me check for one-stop flights as well:
# Tool #6: search_onestop_flight
#
# Tool #7: search_onestop_flight
#
# Tool #8: search_onestop_flight
# Based on the information I've gathered, I'll analyze the flight options for you:
#
# From your requirements:
# - Flying from New York to Seattle on May 20, 2024 (one way)
# - Not flying before 11am EST
# - Economy class
# - Prefer direct flights, but one stopover is acceptable
# - Prefer lowest price if multiple options
# - You'll have 3 baggages
# - No insurance
# - Prefer to use your two certificates (one for $250 and one for $100)
# - If only one certificate can be used, you prefer the larger one ($250) with remaining balance on your Visa card ending in 7447
#
# I found a direct flight from JFK to Seattle that meets your requirements:
#
# HAT069:
# - JFK to SEA (direct)
# - Departure: May 20, 2024 at 06:00 EST (This is before your preferred time of 11am EST)
#
# Let me find another option that departs after 11am. From the one-stop options that depart after 11am, the best option appears to be:
#
# Option from EWR:
# - Flight 1: HAT213 - EWR to DFW
#   - Departure: May 20, 2024 at 12:00 EST
#   - Arrival: May 20, 2024 at 15:30 EST
# - Flight 2: HAT099 - DFW to SEA
#   - Departure: May 20, 2024 at 16:00 EST
#   - Arrival: May 20, 2024 at 20:00 EST
# - Total price in economy: Would be calculated based on both flights
#
# Would you like me to proceed with booking this one-stop flight from EWR (Newark) to Seattle? Since there are no direct flights after 11am EST, this appears to be the best option meeting your criteria.I'll help you with your flight modification or cancellation. First, let's retrieve your reservation details using your user ID.
# Tool #9: get_user_details
# Now let's check each of your reservations to find the one for your trip to Texas.
# Tool #10: get_reservation_details
# I found your reservation for the trip to Texas. Let me confirm the details:
#
# Reservation ID: Z7GOZK
# Origin: EWR (Newark)
# Destination: EWR (Newark, as a round trip)
# Flight type: One-way (though this appears to be a same-day round trip)
# Cabin: Basic economy
# Flights:
# 1. EWR to IAH (Houston, Texas) on May 28, 2024 - Flight HAT188
# 2. IAH (Houston, Texas) to EWR on May 28, 2024 - Flight HAT207
# Travel Insurance: Yes
#
# I understand you want to change your return flight from Houston (IAH) to Newark (EWR) to a later time on the same day (May 28) or possibly the next day.
#
# Since your reservation is for a basic economy ticket, modification options are limited. Basic economy tickets cannot typically be modified for flight changes. However, you mentioned you have travel insurance and are feeling unwell, which would allow you to cancel the reservation.
#
# You have two options:
#
# 1. Cancel the reservation using your travel insurance due to feeling unwell, then book a new reservation with your preferred flight times.
# 2. Transfer to a human agent who might be able to provide other options.
#
# Would you like to proceed with canceling your reservation so you can book a new one with your preferred return flight time?  [2/5] HelpfulnessEvaluator...
# I'll help you find a flight from New York to Seattle on May 20th. Let me first get your user details and check the available flights.
# Tool #11: get_user_details
# Now I need to check what airports are available in New York and Seattle.
# Tool #12: list_all_airports
# I see you'd like to fly from New York to Seattle on May 20th, one-way, in economy class. New York has two airports: JFK and LGA (LaGuardia). Let me check direct flights from both airports to Seattle (SEA) first.
# Tool #13: search_direct_flight
#
# Tool #14: search_direct_flight
# Now let me check one-stop flights from JFK and LGA to SEA, since you mentioned you're open to that option as well.
# Tool #15: search_onestop_flight
#
# Tool #16: search_onestop_flight
# Let me analyze the flight options for you based on your preferences:
#
# 1. You want to fly from New York to Seattle on May 20
# 2. You don't want to fly before 11am EST
# 3. You want economy class
# 4. You prefer direct flights but one stopover is acceptable
# 5. You prefer the lowest price option
#
# Here are the available direct flights from JFK to Seattle that meet your time requirement:
#
# 1. HAT069: JFK → SEA
#    - Departure: 6:00 AM EST (This departs before your preferred time of 11 AM)
#    - Price: $121 (economy)
#
# There are no direct flights from JFK to Seattle after 11 AM EST, and no direct flights from LaGuardia to Seattle on that date.
#
# For connecting flights, the most affordable option that meets your time preference would be:
#
# HAT268 + HAT039: JFK → ATL → SEA
# - First leg: JFK → ATL, departs at 7:00 AM EST (This departs before your preferred time of 11 AM)
# - Second leg: ATL → SEA, departs at 10:00 PM EST
# - Total economy price: $101 + $103 = $204
#
# Since there are no flights that meet both your departure time preference (after 11 AM) and your preference for direct flights, would you like to:
#
# 1. Take the direct flight HAT069 (JFK → SEA) at 6:00 AM for $121 in economy
# 2. Consider a connecting flight with a later departure time
# 3. Change your time preference to find more options
#
# Please let me know which option you prefer, and I can proceed with the booking.I'll help you check your reservation and see if we can modify your return flight. Let me first get your user details to find your reservation.
# Tool #17: get_user_details
# I can see you have several reservations. Let me check each one to find your trip to Texas.
# Tool #18: get_reservation_details
# I found your reservation to Texas! Let me first check to see what airports we're dealing with to confirm the locations.
# Tool #19: list_all_airports
# Now I have all the information I need. Here are the details of your reservation:
#
# - Reservation ID: Z7GOZK
# - Trip: Round trip from Newark (EWR) to Houston, Texas (IAH) on May 28, 2024
# - Cabin: Basic Economy
# - Your return flight (HAT207) is scheduled to depart from Houston at 3pm on May 28, 2024
# - You have travel insurance
#
# Since you have a basic economy ticket, flight modifications are not allowed. However, since you have travel insurance and you mentioned feeling unwell, you can cancel the trip and book again later.
#
# Would you like me to:
# 1. Cancel your current reservation using your travel insurance due to your health concern
# 2. Check available flights from Houston (IAH) to Newark (EWR) later on May 28 or early May 29 (for your information before deciding to cancel)  [3/5] GoalSuccessRateEvaluator...
# I'll help you book a flight from New York to Seattle on May 20. Let me start by gathering the necessary information and searching for flights that match your preferences.
#
# First, let's check your user details to confirm your available payment methods and membership status.
# Tool #20: get_user_details
# Now, let's check the available airports in New York and Seattle to use for our search.
# Tool #21: list_all_airports
# Let me search for direct flights from New York (JFK) to Seattle (SEA) on May 20, 2024.
# Tool #22: search_direct_flight
# Let's also check flights from LaGuardia (LGA) in New York.
# Tool #23: search_direct_flight
# Let's check flights from Newark (EWR) as well.
# Tool #24: search_direct_flight
# Let me search for one-stop flights from JFK to Seattle in case there are better options.
# Tool #25: search_onestop_flight
# Let's search for one-stop flights from LaGuardia (LGA) to Seattle.
# Tool #26: search_onestop_flight
# Let me also check one-stop flights from Newark (EWR) to Seattle.
# Tool #27: search_onestop_flight
# Based on your requirements:
# 1. Flying from New York to Seattle on May 20 (one way)
# 2. Departure after 11 AM EST
# 3. Economy class
# 4. Preference for direct flights
# 5. If multiple options, prefer lowest price
# 6. You need to accommodate 3 baggages
# 7. No insurance
# 8. Payment using certificates and credit card if needed
#
# I found a suitable direct flight option:
#
# From JFK to SEA:
# - Flight Number: HAT069
# - Departure: 2024-05-20, 06:00:00 EST
# - Arrival: 2024-05-20, 12:00:00 EST
# - Economy Price: $121
#
# However, this flight departs at 6 AM EST, which is earlier than your preferred time of 11 AM EST.
#
# From the one-stop flight options that depart after 11 AM EST, I've identified the following best option from EWR (Newark):
# - Flight 1: HAT213 from EWR to DFW, departing at 12:00 PM EST
# - Flight 2: HAT099 from DFW to SEA, departing at 4:00 PM EST
# - Total economy price: $106 + $173 = $279
#
# However, there are no economy seats available on the first leg (EWR to DFW), only basic economy.
#
# Let me check if there's a suitable flight from JFK that meets your timing requirements and has economy seats available.
# Tool #28: think
# Based on your requirements, I'd like to confirm the following details before booking:
#
# 1. Since there are no direct flights from New York to Seattle departing after 11 AM EST on May 20, I recommend the following one-stop flight:
#    - Flight 1: HAT231 (EWR to DFW), departing at 4:00 PM EST, arriving at 7:30 PM EST
#    - Flight 2: HAT067 (DFW to SEA), departing at 11:00 PM EST, arriving at 3:00 AM EST (next day)
#    - Total price in economy class: $171 + $149 = $320
#
# 2. Since you're a gold member, you get 3 free checked bags in economy class, so there would be no extra charge for your 3 bags.
#
# 3. For payment, I'll use your $250 certificate (certificate_7504069) and your Visa card ending in 7447 for the remaining $70.
#
# 4. No insurance will be added as per your request.
#
# May I have your full name and date of birth to complete the booking? Also, please confirm if you'd like to proceed with this flight option.I'll help you with modifying or potentially canceling your reservation. Let's first get your reservation details using your user ID.
# Tool #29: get_user_details
# Now I'll retrieve the details of your reservations to find the one for your trip to Texas.
# Tool #30: get_reservation_details
#
# Tool #31: get_reservation_details
#
# Tool #32: get_reservation_details
# I've found your reservation for the trip to Texas. It's reservation ID Z7GOZK. Let me summarize the details:
#
# - Reservation ID: Z7GOZK
# - Flight type: One-way (technically, it appears to be a round-trip on the same day)
# - Cabin class: Basic Economy
# - Outbound: EWR (Newark) to IAH (Houston, Texas) on May 28, 2024
# - Return: IAH (Houston, Texas) to EWR (Newark) on May 28, 2024
# - The return flight is HAT207 on May 28, 2024
# - You have travel insurance: Yes
#
# I notice that you have a Basic Economy ticket. Unfortunately, Basic Economy tickets cannot be modified according to airline policy. However, since you have travel insurance and you mentioned feeling unwell, you can cancel the reservation and book a new one.
#
# Would you like me to:
# 1. Cancel your current reservation using your travel insurance due to illness, or
# 2. Check availability for new flights from Houston (IAH) to Newark (EWR) for later on May 28 or early May 29 before making a decision?  [4/5] ToolSelectionAccuracyEvaluator...
# I'll help you book a flight from New York to Seattle on May 20. Let me gather the necessary information and search for flights that meet your criteria.
#
# First, let me check your user details to verify your payment methods and membership status.
# Tool #33: get_user_details
# Now, let me check the available airports to identify the correct New York airport codes.
# Tool #34: list_all_airports
# Let me search for direct flights from New York airports (JFK, LGA, EWR) to Seattle (SEA) on May 20, 2024, after 11am EST.
# Tool #35: search_direct_flight
# Let me check if there are direct flights from LaGuardia (LGA) to Seattle:
# Tool #36: search_direct_flight
# Let me check if there are direct flights from Newark (EWR) to Seattle:
# Tool #37: search_direct_flight
# Let me look for one-stop flights from JFK to Seattle, as none of the direct flights from JFK meet the requirement of departing after 11am EST:
# Tool #38: search_onestop_flight
# Let me check for one-stop flights from LGA to Seattle that depart after 11am EST:
# Tool #39: search_onestop_flight
# Let me check for one-stop flights from EWR to Seattle that depart after 11am EST:
# Tool #40: search_onestop_flight
# Based on your requirements, I've found several flight options for you. The best option that meets all your criteria is:
#
# From Newark (EWR) to Seattle (SEA), one-stop flight on May 20:
# - Flight HAT213: EWR to DFW, departing at 12:00 PM EST
# - Flight HAT099: DFW to SEA, departing at 16:00 PM EST
#
# This option offers economy class travel with a departure after 11am EST and has one stopover in Dallas (DFW). The total cost would be approximately $173 for the economy class ticket.
#
# Before I proceed with booking, I need to collect some passenger information:
#
# 1. Is this booking for just yourself, or are there other passengers?
# 2. Could you please confirm your full name and date of birth?
#
# Once I have this information, I can calculate the total cost including your 3 bags and process the payment using your certificates. As a Gold member, you're entitled to 3 free checked bags in economy class, so there will be no additional baggage fees.I'll help you with your request. First, let's check your user details to find your reservation information.
# Tool #41: get_user_details
# I can see you have three reservations in your account. Let's check each to find your trip to Texas.
# Tool #42: get_reservation_details
# I found your reservation to Texas! The reservation ID is Z7GOZK. You have a one-way trip (though it appears to be a round trip on the same day) from Newark (EWR) to Houston (IAH) in Texas on May 28, 2024. Your current return flight is HAT207 from Houston to Newark on May 28.
#
# I see that your ticket is a basic economy class and you do have travel insurance. As per the policy, basic economy flights cannot be modified. Since you mentioned you're feeling unwell and have travel insurance, we can proceed with canceling the reservation and you can book a new flight later.
#
# Before I proceed with the cancellation, I want to confirm:
#
# 1. Are you sure you want to cancel your reservation Z7GOZK (EWR-IAH-EWR on May 28)?
# 2. The reason for cancellation would be that you're feeling unwell, which is covered by your travel insurance.
#
# Please confirm if you would like to proceed with the cancellation.  [5/5] ToolParameterAccuracyEvaluator...
# I'll help you find a suitable flight from New York to Seattle on May 20th. Let me start by checking your user details and then search for available flights.
# Tool #43: get_user_details
# Now, let me check all available airports to find the right codes for New York and Seattle.
# Tool #44: list_all_airports
# Great! Now I'll search for direct flights from JFK to SEA on May 20th. I'll also check from other New York airports (EWR and LGA) to give you more options.
# Tool #45: search_direct_flight
# Let me also check flights from LaGuardia (LGA):
# Tool #46: search_direct_flight
# Now let me check flights from Newark (EWR):
# Tool #47: search_direct_flight
# I see there are only direct flights from JFK to SEA, but both depart before 11am EST. Let me also check for one-stop flights that might depart after 11am:
# Tool #48: search_onestop_flight
# Let me also check one-stop flights from EWR and LGA:
# Tool #49: search_onestop_flight
#
# Tool #50: search_onestop_flight
# Based on my search, I've found several flight options that match your criteria. Since you mentioned not wanting to fly before 11am EST, I'll focus on flights departing after that time.
#
# The most suitable option is from EWR (Newark) with one stopover in Dallas:
# - Flight HAT213: EWR to DFW, departing at 12:00 PM EST
# - Flight HAT099: DFW to SEA, departing at 4:00 PM EST, arriving in Seattle at 8:00 PM
#
# The total price for economy on this route would be $279 ($106 + $173), but unfortunately, there are 0 economy seats available on the first segment (EWR to DFW), only basic economy.
#
# Another good option is from JFK with a stopover in Atlanta:
# - Flight HAT136: JFK to ATL, departing at 7:00 PM EST
# - Flight HAT039: ATL to SEA, departing at 10:00 PM EST, arriving at 3:00 AM the next day
#
# The total price for economy on this route would be $255 ($152 + $103).
#
# Given your preferences and the availability:
# 1. You're a Gold member, which means you get 3 free checked bags in economy class, so all your bags would be covered.
# 2. You wanted to use two certificates for payment. You have two certificates: one for $100 and one for $250.
#
# Before I proceed with booking, could you confirm which flight option you prefer:
# 1. The EWR-DFW-SEA route (however, only basic economy is available for the first leg)
# 2. The JFK-ATL-SEA route (economy is available for the entire journey)
#
# Also, please confirm your passenger details (first name, last name, and date of birth) for the booking.I'll help you with your reservation changes. First, let me check your user details to find your reservation information.
# Tool #51: get_user_details
# Now, I'll check each of your reservations to find the one for your trip to Texas.
# Tool #52: get_reservation_details
# I found your reservation to Texas. Let me review the details:
#
# Reservation ID: Z7GOZK
# Origin: EWR (Newark)
# Destination: EWR (Newark)
# Flight type: one_way (although this appears to be a round-trip since you have two flight segments)
# Cabin: basic_economy
# Flights:
# - Outbound: EWR to IAH (Houston, Texas) on May 28, 2024
# - Return: IAH (Houston, Texas) to EWR on May 28, 2024
# Insurance: yes
#
# I see your concern. You have a basic economy ticket which typically cannot be modified, but you do have travel insurance. Your current return flight is HAT207 from Houston (IAH) to Newark (EWR) on May 28th.
#
# Let me check what other flight options are available from Houston to Newark on May 28th at a later time:
# Tool #53: search_direct_flight
# Now let me also check flights for the next day:
# Tool #54: search_direct_flight
# I've reviewed your reservation and the available flights. Here's what I found:
#
# 1. Your current reservation (Z7GOZK) is a basic economy ticket, which typically cannot be modified.
# 2. You do have travel insurance on this reservation, which allows for cancellation if you are feeling unwell.
# 3. Your current return flight (HAT207) departs at 3:00 PM (15:00) from Houston (IAH) to Newark (EWR) on May 28.
#
# Since you have a basic economy ticket that cannot be modified but you have travel insurance and are feeling unwell, you have two options:
#
# 1. Cancel your current reservation using the travel insurance due to your illness
# 2. Keep your current reservation as is
#
# If you would like to cancel the reservation using your travel insurance, I can assist with that. Then you could book a new reservation with a later flight on May 28 or an early flight on May 29.
#
# Would you like me to help you cancel your current reservation? If so, I'll need your confirmation before proceeding.Sonnet evaluation complete (5 evaluation rounds)

# %% [markdown]
# #### Sonnet Results
#
# Display evaluation results for Claude Sonnet.

# %%
print("\n" + "=" * 80)
print("CLAUDE SONNET RESULTS")
print("=" * 80)

print("\n[1/5] OUTPUT QUALITY")
print("-" * 80)
report_sonnet_output.display()

print("\n[2/5] HELPFULNESS")
print("-" * 80)
report_sonnet_helpfulness.display()

print("\n[3/5] GOAL SUCCESS RATE")
print("-" * 80)
report_sonnet_goal.display()

print("\n[4/5] TOOL SELECTION ACCURACY")
print("-" * 80)
report_sonnet_tool_selection.display()

print("\n[5/5] TOOL PARAMETER ACCURACY")
print("-" * 80)
report_sonnet_tool_parameter.display()
# Out:
# ================================================================================
# CLAUDE SONNET RESULTS
# ================================================================================
#
# [1/5] OUTPUT QUALITY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.77           Pass Rate: 1.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.70  │ ✅        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.85  │ ✅        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [2/5] HELPFULNESS
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [3/5] GOAL SUCCESS RATE
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [4/5] TOOL SELECTION ACCURACY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [5/5] TOOL PARAMETER ACCURACY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘

# %% [markdown]
# ### Run Evaluation: Nova Lite
#
# Evaluate the Nova Lite agent variant on all test cases.

# %%
# Define agent task function for Nova Lite
def agent_task_nova(case: Case) -> str:
    """Execute Nova Lite agent with the given case input."""
    agent_nova_lite.messages = []
    response = agent_nova_lite(case.input)
    return str(response)

# Run evaluations for all 5 evaluators
print("[EVALUATING NOVA LITE]")
print("Running evaluation on Nova Lite agent...")

print("  [1/5] OutputEvaluator...")
report_nova_output = dataset_output.run_evaluations(agent_task_nova)

print("  [2/5] HelpfulnessEvaluator...")
report_nova_helpfulness = dataset_helpfulness.run_evaluations(agent_task_nova)

print("  [3/5] GoalSuccessRateEvaluator...")
report_nova_goal = dataset_goal.run_evaluations(agent_task_nova)

print("  [4/5] ToolSelectionAccuracyEvaluator...")
report_nova_tool_selection = dataset_tool_selection.run_evaluations(agent_task_nova)

print("  [5/5] ToolParameterAccuracyEvaluator...")
report_nova_tool_parameter = dataset_tool_parameter.run_evaluations(agent_task_nova)

print("Nova Lite evaluation complete (5 evaluation rounds)")
# Out:
# [EVALUATING NOVA LITE]
# Running evaluation on Nova Lite agent...
#   [1/5] OutputEvaluator...
# <thinking>I need to first confirm Mia's user ID, and then use the tool to search for flights from New York to Seattle on May 20 that meet her requirements (one-way, economy, no early flights, preference for direct flights, lowest price, 3 baggages, no insurance, and payment details). I'll need to get the details of the flights to proceed with booking.</thinking>
#
# Tool #1: search_direct_flight
#
# Tool #2: search_onestop_flight
# <thinking>It seems there are no direct or one-stop flights available from New York to Seattle on May 20 that meet the specified criteria. I should inform Mia about this and suggest alternative options or dates.</thinking>
#
# Hi Mia, I searched for flights from New York to Seattle on May 20 based on your criteria, but unfortunately, there are no direct or one-stop flights available at the moment. If you're flexible with your travel dates or destination, I can help you explore other options. Alternatively, you may want to check back later as flight availability can change.<thinking>First, I need to confirm the user's membership status and verify if Newark (EWR) and Texas airports are available for direct flights. Then, I need to check the reservation details to determine if the return flight can be modified or if the trip needs to be canceled using travel insurance. Lastly, I need to ask the user for the necessary details to book a new flight if needed.</thinking>
#
# Tool #3: get_user_details
# <thinking>Olivia is a regular member and her reservation IDs are Z7GOZK, K67C4W, and THY2DG. I need to check her reservation details to determine which flight needs to be modified or canceled. Since she cannot accept flights from JFK, I should verify if Newark (EWR) and Texas airports are available for direct flights.</thinking>
# Tool #4: search_direct_flight
#
# Tool #5: get_reservation_details
#
# Tool #6: get_reservation_details
#
# Tool #7: get_reservation_details
# <thinking>Olivia's reservation with ID Z7GOZK is for a trip from Newark to Houston and back on May 28, 2024. Since the return flight is a basic economy flight, it cannot be modified. She has travel insurance for this reservation, so we can cancel the trip using it. If she feels better, we can book a new flight for her.</thinking>
#
# Hi Olivia, I have reviewed your reservation details. Your return flight from Texas to Newark on May 28, 2024, is a basic economy flight and cannot be modified. However, you have travel insurance for this reservation, so we can cancel the trip using it.
#
# If you feel better, we can book a new flight for you. Please confirm if you want to proceed with the cancellation using travel insurance and if you would like to book a new flight. If you confirm, I will proceed with the cancellation and then assist you with booking a new flight.  [2/5] HelpfulnessEvaluator...
# <thinking>I need to gather more information about Mia Li's preferences before I can proceed with booking the flight. First, I should verify if Mia Li's certificates are sufficient to cover the flight cost. If not, I will need to know which certificate to use first and how to cover the remaining cost.</thinking>
#
# Tool #8: get_user_details
# <thinking>I now have Mia Li's payment details. She has two certificates worth $100 and $250 respectively. I will need to determine the total cost of the flight and see if her certificates are sufficient. If not, I will need to know which certificate to use first and how to cover the remaining cost.</thinking>
#
#
# Tool #9: search_direct_flight
#
# Tool #10: search_onestop_flight
# <thinking>There are no direct flights available on May 20 from New York to Seattle. I will need to inform Mia Li that there are no direct flights available and proceed with a one-stop flight if she agrees.</thinking>
#
# Hi Mia, I'm sorry to inform you that there are no direct flights available on May 20 from New York to Seattle. However, I can search for one-stop flights that meet your preferences. Would you like me to proceed with that? If so, please confirm.<thinking>First, I need to determine the user's reservation id. I will then check the reservation details to see if the flight can be modified. If the flight cannot be modified, I will check if the user has travel insurance and if the conditions for using it are met. If so, I will proceed with cancelling the reservation using the travel insurance. If not, I will inform the user that they cannot modify the flight and suggest rebooking later.</thinking>
#
# Tool #11: get_user_details
# <thinking>I have retrieved the user's reservation details. I need to check the details of each reservation to find the one related to the trip to Texas. Once I have the reservation details, I will check if the return flight can be modified or if it is a basic economy ticket that cannot be modified. If it cannot be modified, I will check if the user has travel insurance and if the conditions for using it are met. If so, I will proceed with cancelling the reservation using the travel insurance. If not, I will inform the user that they cannot modify the flight and suggest rebooking later.</thinking>
# Tool #12: get_reservation_details
#
# Tool #13: get_reservation_details
#
# Tool #14: get_reservation_details
# <thinking>The user's reservation with the ID Z7GOZK is the one related to the trip to Texas. The return flight is a basic economy ticket and cannot be modified. The user has travel insurance, and the conditions for using it are met. I will proceed with cancelling the reservation using the travel insurance.</thinking>
# Tool #15: cancel_reservation
# <thinking>The reservation has been successfully cancelled using the travel insurance. The refund will be processed and will be credited back to the original payment method used in 5 to 7 business days. I will inform the user about the cancellation and the refund process.</thinking>
#
# Hi Olivia, your reservation for the trip to Texas has been successfully cancelled using your travel insurance. The refund will be processed and will be credited back to the original payment method used in 5 to 7 business days. If you need to book a new flight, please let me know.  [3/5] GoalSuccessRateEvaluator...
# <thinking>I need to first obtain the user's details to ensure I can proceed with booking the flight. Then, I need to search for flights from New York to Seattle on May 20 that do not depart before 11am EST, prefer direct flights but are also fine with one stopover, and are in economy. I should also consider the lowest price option. The user has 3 baggages and does not want insurance. The user wants to use their two certificates to pay, but if only one certificate can be used, they prefer using the larger one and paying the rest with their 7447 card.</thinking>
#
# Tool #16: get_user_details
# <thinking>I have the user's details. Now, I need to search for flights from New York to Seattle on May 20 that do not depart before 11am EST, prefer direct flights but are also fine with one stopover, and are in economy. I should also consider the lowest price option. The user has 3 baggages and does not want insurance. The user wants to use their two certificates to pay, but if only one certificate can be used, they prefer using the larger one and paying the rest with their 7447 card.</thinking>
# Tool #17: search_direct_flight
#
# Tool #18: search_onestop_flight
# <thinking>I have found several flight options. I need to select the option that meets the user's preferences: not departing before 11am EST, prefers direct flights but is also fine with one stopover, and is in economy. I should also consider the lowest price option. The user has 3 baggages and does not want insurance. The user wants to use their two certificates to pay, but if only one certificate can be used, they prefer using the larger one and paying the rest with their 7447 card.</thinking>
#
# Here are the flight options:
#
# 1. Direct Flight HAT069: Departs at 06:00 EST, Arrives at 12:00 EST, Economy price is $121.
# 2. Direct Flight HAT083: Departs at 01:00 EST, Arrives at 07:00 EST, Economy price is $100.
# 3. One-stop Flight HAT057 + HAT039: Departs at 07:00 EST, Arrives at 03:00 EST next day, Economy price is $103.
# 4. One-stop Flight HAT136 + HAT039: Departs at 19:00 EST, Arrives at 03:00 EST next day, Economy price is $103.
# 5. One-stop Flight HAT218 + HAT039: Departs at 18:00 EST, Arrives at 03:00 EST next day, Economy price is $103.
# 6. One-stop Flight HAT268 + HAT039: Departs at 07:00 EST, Arrives at 03:00 EST next day, Economy price is $103.
#
# The lowest price option is the direct flight HAT083 at $100. However, it departs before 11am EST. The next lowest price options are the one-stop flights at $103, which all depart after 11am EST.
#
# I will proceed with booking the one-stop flight HAT057 + HAT039, as it is the lowest price option that meets the user's preference of not departing before 11am EST.</thinking>
# Tool #19: book_reservation
# <thinking>There was an error in the booking process because the 'payment_id' was not provided. I need to correct this by specifying the payment IDs for the certificates and credit card.</thinking>
# Tool #20: book_reservation
# <thinking>There was another error because the 'payment_id' was still not provided. I need to correct this by specifying the payment IDs for the certificates and credit card again.</thinking>
# Tool #21: book_reservation
# <thinking>There was another error because the 'payment_id' was still not provided. I need to correct this by specifying the payment IDs for the certificates and credit card again.</thinking>
# Tool #22: book_reservation
# <thinking>There was another error because the 'payment_id' was still not provided. I need to correct this by specifying the payment IDs for the certificates and credit card again.</thinking>
# Tool #23: book_reservation
# <thinking>I'm sorry for the inconvenience. There seems to be a persistent issue with the booking process due to the 'payment_id' not being recognized. I will need to transfer this request to a human agent for further assistance.</thinking>
# Tool #24: transfer_to_human_agents
# <thinking>The request has been successfully transferred to a human agent for further assistance.</thinking>
#
# I'm sorry for the inconvenience. There seems to be a persistent issue with the booking process due to the 'payment_id' not being recognized. I have transferred your request to a human agent who will assist you further. Please wait for their response.<thinking>First, I need to confirm if Newark is the airport code EWR. Then, I need to retrieve the reservation details using the user's id and check the current flight details. After that, I will determine if the flight can be modified or if the reservation needs to be canceled using travel insurance. I will start by confirming Newark's airport code and then proceed to retrieve the reservation details.</thinking>
#
# Tool #25: list_all_airports
# <thinking>Newark's airport code is indeed EWR. Next, I will retrieve the reservation details using  [4/5] ToolSelectionAccuracyEvaluator...
# <thinking>First, I need to search for flights from New York to Seattle on May 20 that depart after 11am EST. Since Mia prefers direct flights but is open to one stopover, I will search for both direct and one-stop flights. I will also ensure the flights are in economy and check the prices to find the lowest one. Finally, I will confirm the details for booking.</thinking>
#
# Tool #26: search_direct_flight
#
# Tool #27: search_onestop_flight
# <thinking>Based on the search results, I have found both direct and one-stop flight options. However, since Mia prefers direct flights but is open to one stopover, I will consider both. I need to check the prices and find the lowest one that departs after 11am EST. After identifying the lowest price option, I will proceed to book the flight.</thinking>
#
# **Direct Flights:**
# 1. Flight HAT069: Departs at 6:00am EST, Economy price: $121
# 2. Flight HAT083: Departs at 1:00am EST, Economy price: $100
#
# **One-Stop Flights:**
# 1. Flight HAT057 + HAT039: Departs at 7:00am EST, Economy price: $141 + $103 = $244
# 2. Flight HAT136 + HAT039: Departs at 7:00pm EST, Economy price: $152 + $103 = $255
# 3. Flight HAT218 + HAT039: Departs at 6:00pm EST, Economy price: $158 + $103 = $261
# 4. Flight HAT268 + HAT039: Departs at 7:00am EST, Economy price: $101 + $103 = $204
#
# The lowest price option is the direct flight HAT083 departing at 1:00am EST for $100. However, since Mia prefers flights that depart after 11am EST, I will need to check the one-stop options that meet this criterion.
#
# The one-stop flight with the lowest price that departs after 11am EST is the combination of Flight HAT136 and HAT039 departing at 7:00pm EST for $255.
#
# Now, I will proceed to book the flight HAT136 + HAT039 with the details provided by Mia.</thinking>
#
#
# Tool #28: book_reservation
# <thinking>It appears there was an error in the booking process because the payment method certificate_7447 was not found. I will need to ask Mia to confirm the correct payment method or provide more details about her certificates.</thinking>
#
# **Hi Mia,**
#
# There was an error in booking your flight because the payment method certificate_7447 was not found. Could you please confirm the correct payment method or provide more details about your certificates? I will need to ensure that the correct payment method is used for the booking.
#
# Thank you,
# [Your Name]<thinking>The user needs to modify their return flight. I first need to determine whether their reservation is a basic economy flight, which cannot be modified. If it is, I'll need to proceed with cancellation using their travel insurance. I'll start by getting the reservation details using the user's ID  [5/5] ToolParameterAccuracyEvaluator...
# <thinking>First, I need to confirm the user's details and then search for available flights between New York and Seattle on May 20. The user prefers direct flights but is also okay with one stopover. I'll need to check both direct and one-stop flights and compare their prices to find the most economical option. I will also need to confirm the user's baggage allowance and payment methods.</thinking>
#
# Tool #29: search_direct_flight
#
# Tool #30: search_onestop_flight
# <thinking>Now that I have the flight details, I'll need to check the available flights to find the most economical option that departs after 11am EST and meets the user's requirements. I will then confirm the details and proceed to book the reservation.</thinking>
#
# Here are the available flights that meet your criteria:
#
# 1. **Direct Flights:**
#    - **Flight HAT069:**
#      - Departure: 06:00:00 EST
#      - Arrival: 12:00:00 EST
#      - Basic Economy: $51
#      - Economy: $121
#      - Business: $239
#    - **Flight HAT083:**
#      - Departure: 01:00:00 EST
#      - Arrival: 07:00:00 EST
#      - Basic Economy: $87
#      - Economy: $100
#      - Business: $276
#
# 2. **One-Stop Flights:**
#    - **Flight HAT057 + HAT039:**
#      - Departure from JFK: 07:00:00 EST
#      - Arrival in SEA: 03:00:00+1 EST
#      - Basic Economy: $128
#      - Economy: $244
#      - Business: $760
#    - **Flight HAT136 + HAT039:**
#      - Departure from JFK: 19:00:00 EST
#      - Arrival in SEA: 03:00:00+1 EST
#      - Basic Economy: $104
#      - Economy: $252
#      - Business: $563
#    - **Flight HAT218 + HAT039:**
#      - Departure from JFK: 18:00:00 EST
#      - Arrival in SEA: 03:00:00+1 EST
#      - Basic Economy: $148
#      - Economy: $261
#      - Business: $625
#    - **Flight HAT268 + HAT039:**
#      - Departure from JFK: 07:00:00 EST
#      - Arrival in SEA: 03:00:00+1 EST
#      - Basic Economy: $143
#      - Economy: $204
#      - Business: $760
#
# The most economical direct flight is **Flight HAT069** departing at 06:00:00 EST and arriving at 12:00:00 EST. However, since you prefer a flight after 11am EST, we'll look at one-stop options.
#
# The most economical one-stop flight is **Flight HAT136 + HAT039** departing at 19:00:00 EST and arriving at 03:00:00+1 EST.
#
# Based on your preference for the lowest price, I recommend **Flight HAT136 + HAT039** for $252 in economy.
#
# Would you like to proceed with booking this flight? If so, please confirm. If you have any other preferences, please let me know.<thinking>To help Olivia with her request, I need to first determine if her reservation can be modified. If it cannot be modified, I need to verify if she has travel insurance and if her flight can be cancelled using it. Here are the steps I will take:
#
# 1. Get the reservation details for Olivia's user id.
# 2. Check if the reservation can be modified.
# 3. If it cannot be modified, check if she has travel insurance and if her flight can be cancelled using it.
# 4. If she can cancel using the travel insurance, confirm the cancellation and offer her a certificate as a gesture of goodwill if she requests it.
# 5. If she wants to book a new flight, INova Lite evaluation complete (5 evaluation rounds)

# %% [markdown]
# #### Nova Lite Results
#
# Display evaluation results for Nova Lite.

# %%
print("\n" + "=" * 80)
print("NOVA LITE RESULTS")
print("=" * 80)

print("\n[1/5] OUTPUT QUALITY")
print("-" * 80)
report_nova_output.display()

print("\n[2/5] HELPFULNESS")
print("-" * 80)
report_nova_helpfulness.display()

print("\n[3/5] GOAL SUCCESS RATE")
print("-" * 80)
report_nova_goal.display()

print("\n[4/5] TOOL SELECTION ACCURACY")
print("-" * 80)
report_nova_tool_selection.display()

print("\n[5/5] TOOL PARAMETER ACCURACY")
print("-" * 80)
report_nova_tool_parameter.display()
# Out:
# ================================================================================
# NOVA LITE RESULTS
# ================================================================================
#
# [1/5] OUTPUT QUALITY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.65           Pass Rate: 0.5                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.70  │ ✅        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.60  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [2/5] HELPFULNESS
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [3/5] GOAL SUCCESS RATE
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [4/5] TOOL SELECTION ACCURACY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘
# [5/5] TOOL PARAMETER ACCURACY
# --------------------------------------------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── 📊 Evaluation Report ──────────────────────────────────────────────╮
# │ Overall Score: 0.00           Pass Rate: 0.0                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                Test Case Results
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ index ┃ name                            ┃ score ┃ test_pass ┃ reason ┃ input ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ ▶ 0   │ Scenario_1_mia_li_3668          │ 0.00  │ ❌        │ ...    │ ...   │
# ├───────┼─────────────────────────────────┼───────┼───────────┼────────┼───────┤
# │ ▶ 1   │ Scenario_2_olivia_gonzalez_2305 │ 0.00  │ ❌        │ ...    │ ...   │
# └───────┴─────────────────────────────────┴───────┴───────────┴────────┴───────┘

# %%
# DEBUG: Inspect report structure to understand how to extract scores
print("=" * 80)
print("DEBUG: Inspecting report_haiku_output structure")
print("=" * 80)

print("\n1. Report type:")
print(f"   {type(report_haiku_output)}")

print("\n2. Report attributes:")
report_attrs = [attr for attr in dir(report_haiku_output) if not attr.startswith('_')]
print(f"   {report_attrs}")

print("\n3. Checking for 'detailed_results' attribute:")
if hasattr(report_haiku_output, 'detailed_results'):
    print(f"   Type: {type(report_haiku_output.detailed_results)}")
    if report_haiku_output.detailed_results:
        print(f"   Length: {len(report_haiku_output.detailed_results)}")
        print(f"   First element type: {type(report_haiku_output.detailed_results[0])}")
        print(f"   First element: {report_haiku_output.detailed_results[0]}")
else:
    print("   'detailed_results' not found!")

print("\n4. Checking for 'results' attribute:")
if hasattr(report_haiku_output, 'results'):
    print(f"   Type: {type(report_haiku_output.results)}")
    if report_haiku_output.results:
        print(f"   Length: {len(report_haiku_output.results)}")
        print(f"   First element type: {type(report_haiku_output.results[0])}")
        print(f"   First element attributes: {[attr for attr in dir(report_haiku_output.results[0]) if not attr.startswith('_')]}")
        print(f"   First element: {report_haiku_output.results[0]}")
        
        # Check if first element has score
        if hasattr(report_haiku_output.results[0], 'score'):
            print(f"   First element score: {report_haiku_output.results[0].score}")
else:
    print("   'results' not found!")

print("\n5. All non-private attributes with values:")
for attr in report_attrs[:10]:  # Show first 10 to avoid too much output
    try:
        value = getattr(report_haiku_output, attr)
        if not callable(value):
            print(f"   {attr}: {type(value)} = {str(value)[:100]}")
    except:
        pass
# Out:
# ================================================================================
# DEBUG: Inspecting report_haiku_output structure
# ================================================================================
#
# 1. Report type:
#    <class 'strands_evals.types.evaluation_report.EvaluationReport'>
#
# 2. Report attributes:
#    ['cases', 'construct', 'copy', 'detailed_results', 'dict', 'display', 'from_dict', 'from_file', 'from_orm', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'overall_score', 'parse_file', 'parse_obj', 'parse_raw', 'reasons', 'run_display', 'schema', 'schema_json', 'scores', 'test_passes', 'to_dict', 'to_file', 'update_forward_refs', 'validate']
#
# 3. Checking for 'detailed_results' attribute:
#    Type: <class 'list'>
#    Length: 2
#    First element type: <class 'list'>
#    First element: [EvaluationOutput(score=0.7, test_pass=True, reason="The output addresses key aspects of the airline request: identifies certificates available, recommends using the larger certificate as preferred, calculates remaining balance for the card, mentions flight details (HAT069, May 20, JFK to SEA, economy, 3 baggages), and asks for confirmation. However, it lacks verification of timing constraints (no flight before 11am EST), doesn't confirm direct/one-stop preference, and doesn't explain how the specific flight was selected from available options.", label='Partially Complete')]
#
# 4. Checking for 'results' attribute:
#    'results' not found!
#
# 5. All non-private attributes with values:
#    cases: <class 'list'> = [{'input': '\nMy user id is mia_li_3668. I want to fly from New York to Seattle on May 20 (one way).
#    detailed_results: <class 'list'> = [[EvaluationOutput(score=0.7, test_pass=True, reason="The output addresses key aspects of the airlin

# %%
# DEBUG: Inspect report structure to understand how to extract scores
print("=" * 80)
print("DEBUG: Inspecting report_haiku_output structure")
print("=" * 80)

print("\n1. Report type:")
print(f"   {type(report_haiku_output)}")

print("\n2. Report attributes:")
report_attrs = [attr for attr in dir(report_haiku_output) if not attr.startswith('_')]
print(f"   {report_attrs}")

print("\n3. Checking for 'detailed_results' attribute:")
if hasattr(report_haiku_output, 'detailed_results'):
    print(f"   Type: {type(report_haiku_output.detailed_results)}")
    if report_haiku_output.detailed_results:
        print(f"   Length: {len(report_haiku_output.detailed_results)}")
        print(f"   First element type: {type(report_haiku_output.detailed_results[0])}")
        print(f"   First element: {report_haiku_output.detailed_results[0]}")
else:
    print("   'detailed_results' not found!")

print("\n4. Checking for 'results' attribute:")
if hasattr(report_haiku_output, 'results'):
    print(f"   Type: {type(report_haiku_output.results)}")
    if report_haiku_output.results:
        print(f"   Length: {len(report_haiku_output.results)}")
        print(f"   First element type: {type(report_haiku_output.results[0])}")
        print(f"   First element attributes: {[attr for attr in dir(report_haiku_output.results[0]) if not attr.startswith('_')]}")
        print(f"   First element: {report_haiku_output.results[0]}")
        
        # Check if first element has score
        if hasattr(report_haiku_output.results[0], 'score'):
            print(f"   First element score: {report_haiku_output.results[0].score}")
else:
    print("   'results' not found!")

print("\n5. All non-private attributes with values:")
for attr in report_attrs[:10]:  # Show first 10 to avoid too much output
    try:
        value = getattr(report_haiku_output, attr)
        if not callable(value):
            print(f"   {attr}: {type(value)} = {str(value)[:100]}")
    except:
        pass
# Out:
# ================================================================================
# DEBUG: Inspecting report_haiku_output structure
# ================================================================================
#
# 1. Report type:
#    <class 'strands_evals.types.evaluation_report.EvaluationReport'>
#
# 2. Report attributes:
#    ['cases', 'construct', 'copy', 'detailed_results', 'dict', 'display', 'from_dict', 'from_file', 'from_orm', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'overall_score', 'parse_file', 'parse_obj', 'parse_raw', 'reasons', 'run_display', 'schema', 'schema_json', 'scores', 'test_passes', 'to_dict', 'to_file', 'update_forward_refs', 'validate']
#
# 3. Checking for 'detailed_results' attribute:
#    Type: <class 'list'>
#    Length: 2
#    First element type: <class 'list'>
#    First element: [EvaluationOutput(score=0.7, test_pass=True, reason="The output addresses key aspects of the airline request: identifies certificates available, recommends using the larger certificate as preferred, calculates remaining balance for the card, mentions flight details (HAT069, May 20, JFK to SEA, economy, 3 baggages), and asks for confirmation. However, it lacks verification of timing constraints (no flight before 11am EST), doesn't confirm direct/one-stop preference, and doesn't explain how the specific flight was selected from available options.", label='Partially Complete')]
#
# 4. Checking for 'results' attribute:
#    'results' not found!
#
# 5. All non-private attributes with values:
#    cases: <class 'list'> = [{'input': '\nMy user id is mia_li_3668. I want to fly from New York to Seattle on May 20 (one way).
#    detailed_results: <class 'list'> = [[EvaluationOutput(score=0.7, test_pass=True, reason="The output addresses key aspects of the airlin

# %%
# Helper function to extract scores from report
def extract_scores(report, evaluator_name: str) -> Dict[str, List[float]]:
    """Extract numeric scores organized by evaluator type.
    
    Args:
        report: EvaluationReport object containing detailed_results
        evaluator_name: Name of the evaluator (e.g., 'OutputEvaluator', 'HelpfulnessEvaluator')
    
    Returns:
        Dictionary mapping evaluator name to list of scores
    """
    scores = defaultdict(list)
    
    # detailed_results is a list of lists of EvaluationOutput objects
    # Each test case has its own list of EvaluationOutput objects
    for test_case_results in report.detailed_results:
        # test_case_results is a list of EvaluationOutput objects for one test case
        for eval_output in test_case_results:
            # eval_output is an EvaluationOutput object with fields: score, test_pass, reason, label
            if hasattr(eval_output, 'score'):
                scores[evaluator_name].append(float(eval_output.score))
    
    return dict(scores)

# Extract scores from all evaluation reports (3 models x evaluators)
scores_haiku = {}
scores_haiku.update(extract_scores(report_haiku_output, 'OutputEvaluator'))
scores_haiku.update(extract_scores(report_haiku_helpfulness, 'HelpfulnessEvaluator'))
scores_haiku.update(extract_scores(report_haiku_goal, 'GoalSuccessRateEvaluator'))
scores_haiku.update(extract_scores(report_haiku_tool_selection, 'ToolSelectionAccuracyEvaluator'))
scores_haiku.update(extract_scores(report_haiku_tool_parameter, 'ToolParameterAccuracyEvaluator'))

scores_sonnet = {}
scores_sonnet.update(extract_scores(report_sonnet_output, 'OutputEvaluator'))
scores_sonnet.update(extract_scores(report_sonnet_helpfulness, 'HelpfulnessEvaluator'))
scores_sonnet.update(extract_scores(report_sonnet_goal, 'GoalSuccessRateEvaluator'))
scores_sonnet.update(extract_scores(report_sonnet_tool_selection, 'ToolSelectionAccuracyEvaluator'))
scores_sonnet.update(extract_scores(report_sonnet_tool_parameter, 'ToolParameterAccuracyEvaluator'))

scores_nova = {}
scores_nova.update(extract_scores(report_nova_output, 'OutputEvaluator'))
scores_nova.update(extract_scores(report_nova_helpfulness, 'HelpfulnessEvaluator'))
scores_nova.update(extract_scores(report_nova_goal, 'GoalSuccessRateEvaluator'))
scores_nova.update(extract_scores(report_nova_tool_selection, 'ToolSelectionAccuracyEvaluator'))
scores_nova.update(extract_scores(report_nova_tool_parameter, 'ToolParameterAccuracyEvaluator'))

# Calculate totals dynamically
num_evaluators = len(scores_haiku)
num_models = 3
total_reports = num_models * num_evaluators

print(f"Scores extracted from all {total_reports} evaluation reports")
print(f"  Haiku: {num_evaluators} evaluation rounds")
print(f"  Sonnet: {num_evaluators} evaluation rounds")
print(f"  Nova: {num_evaluators} evaluation rounds")
print(f"\nEvaluator types found:")
for evaluator_name in scores_haiku.keys():
    print(f"  - {evaluator_name}")
# Out:
# Scores extracted from all 3 evaluation reports
#   Haiku: 1 evaluation rounds
#   Sonnet: 1 evaluation rounds
#   Nova: 1 evaluation rounds
#
# Evaluator types found:
#   - OutputEvaluator

# %% [markdown]
# ### Calculate Statistical Measures
#
# Compute mean and standard deviation for each evaluator across all models.

# %%
# Calculate statistics for each model
def calculate_statistics(scores: Dict[str, List[float]]) -> Dict[str, Dict[str, float]]:
    """Calculate mean and standard deviation for each evaluator."""
    stats = {}
    
    for evaluator_name, score_list in scores.items():
        if len(score_list) > 0:
            mean_score = statistics.mean(score_list)
            std_dev = statistics.stdev(score_list) if len(score_list) > 1 else 0.0
            stats[evaluator_name] = {
                "mean": mean_score,
                "std_dev": std_dev,
                "count": len(score_list)
            }
    
    return stats

# Calculate for all models
stats_haiku = calculate_statistics(scores_haiku)
stats_sonnet = calculate_statistics(scores_sonnet)
stats_nova = calculate_statistics(scores_nova)

# %% [markdown]
# ### Side-by-Side Comparison
#
# Display evaluation scores side-by-side for direct comparison across models.

# %%
# Create comparison table
comparison_md = "## Model Performance Comparison\n\n"
comparison_md += "### Mean Scores by Evaluator\n\n"
comparison_md += "| Evaluator | Claude Haiku | Claude Sonnet | Nova Lite |\n"
comparison_md += "|:----------|-------------:|--------------:|----------:|\n"

# Get all evaluator names
all_evaluators = set(stats_haiku.keys()) | set(stats_sonnet.keys()) | set(stats_nova.keys())

for evaluator_name in sorted(all_evaluators):
    haiku_mean = stats_haiku.get(evaluator_name, {}).get('mean', 0.0)
    sonnet_mean = stats_sonnet.get(evaluator_name, {}).get('mean', 0.0)
    nova_mean = stats_nova.get(evaluator_name, {}).get('mean', 0.0)
    
    # Highlight best score
    max_score = max(haiku_mean, sonnet_mean, nova_mean)
    
    haiku_str = f"**{haiku_mean:.3f}**" if haiku_mean == max_score else f"{haiku_mean:.3f}"
    sonnet_str = f"**{sonnet_mean:.3f}**" if sonnet_mean == max_score else f"{sonnet_mean:.3f}"
    nova_str = f"**{nova_mean:.3f}**" if nova_mean == max_score else f"{nova_mean:.3f}"
    
    comparison_md += f"| {evaluator_name} | {haiku_str} | {sonnet_str} | {nova_str} |\n"

comparison_md += "\n*Bold indicates best performance for that evaluator*\n"

display(Markdown(comparison_md))
# Out:
# ## Model Performance Comparison
#
# ### Mean Scores by Evaluator
#
# | Evaluator | Claude Haiku | Claude Sonnet | Nova Lite |
# |:----------|-------------:|--------------:|----------:|
# | OutputEvaluator | 0.700 | **0.775** | 0.650 |
#
# *Bold indicates best performance for that evaluator*

# %% [markdown]
# ### Statistical Variability Analysis
#
# Examine the standard deviation to understand consistency across test cases.

# %%
# Create variability table
variability_md = "## Performance Variability (Standard Deviation)\n\n"
variability_md += "| Evaluator | Claude Haiku | Claude Sonnet | Nova Lite |\n"
variability_md += "|:----------|-------------:|--------------:|----------:|\n"

for evaluator_name in sorted(all_evaluators):
    haiku_std = stats_haiku.get(evaluator_name, {}).get('std_dev', 0.0)
    sonnet_std = stats_sonnet.get(evaluator_name, {}).get('std_dev', 0.0)
    nova_std = stats_nova.get(evaluator_name, {}).get('std_dev', 0.0)
    
    # Highlight lowest variability (most consistent)
    min_std = min(haiku_std, sonnet_std, nova_std) if any([haiku_std, sonnet_std, nova_std]) else 0
    
    haiku_str = f"**{haiku_std:.3f}**" if haiku_std == min_std and min_std > 0 else f"{haiku_std:.3f}"
    sonnet_str = f"**{sonnet_std:.3f}**" if sonnet_std == min_std and min_std > 0 else f"{sonnet_std:.3f}"
    nova_str = f"**{nova_std:.3f}**" if nova_std == min_std and min_std > 0 else f"{nova_std:.3f}"
    
    variability_md += f"| {evaluator_name} | {haiku_str} | {sonnet_str} | {nova_str} |\n"

variability_md += "\n*Bold indicates lowest variability (most consistent performance)*\n"
variability_md += "\n**Lower standard deviation = More consistent performance across test cases**\n"

display(Markdown(variability_md))
# Out:
# ## Performance Variability (Standard Deviation)
#
# | Evaluator | Claude Haiku | Claude Sonnet | Nova Lite |
# |:----------|-------------:|--------------:|----------:|
# | OutputEvaluator | 0.000 | 0.106 | 0.071 |
#
# *Bold indicates lowest variability (most consistent performance)*
#
# **Lower standard deviation = More consistent performance across test cases**

# %% [markdown]
# ### Cost-Performance Analysis
#
# Analyze cost-performance trade-offs based on AWS Bedrock pricing.

# %%
# Approximate pricing (as of 2024, per 1K tokens)
# Note: Actual pricing may vary by region and over time
pricing = {
    "haiku": {"input": 0.00025, "output": 0.00125},  # Haiku pricing
    "sonnet": {"input": 0.003, "output": 0.015},    # Sonnet pricing
    "nova_lite": {"input": 0.00006, "output": 0.00024}  # Nova Lite pricing
}

# Create cost-performance summary
cost_md = "## Cost-Performance Trade-offs\n\n"
cost_md += "### Approximate Pricing (per 1K tokens)\n\n"
cost_md += "| Model | Input Cost | Output Cost | Relative Cost |\n"
cost_md += "|:------|:-----------|:------------|:--------------|\n"

# Calculate relative costs (normalized to Haiku)
haiku_total = pricing["haiku"]["input"] + pricing["haiku"]["output"]
sonnet_total = pricing["sonnet"]["input"] + pricing["sonnet"]["output"]
nova_total = pricing["nova_lite"]["input"] + pricing["nova_lite"]["output"]

cost_md += f"| Claude Haiku | ${pricing['haiku']['input']:.5f} | ${pricing['haiku']['output']:.5f} | 1.0x (baseline) |\n"
cost_md += f"| Claude Sonnet | ${pricing['sonnet']['input']:.5f} | ${pricing['sonnet']['output']:.5f} | {sonnet_total/haiku_total:.1f}x |\n"
cost_md += f"| Nova Lite | ${pricing['nova_lite']['input']:.6f} | ${pricing['nova_lite']['output']:.6f} | {nova_total/haiku_total:.2f}x |\n"

cost_md += "\n*Note: Pricing is approximate and may vary by region*\n"

display(Markdown(cost_md))
# Out:
# ## Cost-Performance Trade-offs
#
# ### Approximate Pricing (per 1K tokens)
#
# | Model | Input Cost | Output Cost | Relative Cost |
# |:------|:-----------|:------------|:--------------|
# | Claude Haiku | $0.00025 | $0.00125 | 1.0x (baseline) |
# | Claude Sonnet | $0.00300 | $0.01500 | 12.0x |
# | Nova Lite | $0.000060 | $0.000240 | 0.20x |
#
# *Note: Pricing is approximate and may vary by region*

# %% [markdown]
# ### Model Selection Recommendations
#
# Generate actionable recommendations based on evaluation results and cost analysis.

# %%
# Calculate overall performance score (simple average of means)
def overall_score(stats: Dict[str, Dict[str, float]]) -> float:
    """Calculate simple average of all mean scores."""
    means = [stat['mean'] for stat in stats.values()]
    return statistics.mean(means) if means else 0.0

overall_haiku = overall_score(stats_haiku)
overall_sonnet = overall_score(stats_sonnet)
overall_nova = overall_score(stats_nova)

# Create recommendations
recommendations_md = "## Model Selection Recommendations\n\n"
recommendations_md += "### Overall Performance Scores\n\n"
recommendations_md += f"- **Claude Haiku**: {overall_haiku:.3f}\n"
recommendations_md += f"- **Claude Sonnet**: {overall_sonnet:.3f}\n"
recommendations_md += f"- **Nova Lite**: {overall_nova:.3f}\n"
recommendations_md += "\n### Use Case Recommendations\n\n"

# Determine winner
best_model = max([("Haiku", overall_haiku), ("Sonnet", overall_sonnet), ("Nova Lite", overall_nova)], key=lambda x: x[1])

recommendations_md += f"**Best Overall Performance**: Claude {best_model[0]}\n\n"
display(Markdown(recommendations_md))
# Out:
# ## Model Selection Recommendations
#
# ### Overall Performance Scores
#
# - **Claude Haiku**: 0.700
# - **Claude Sonnet**: 0.775
# - **Nova Lite**: 0.650
#
# ### Use Case Recommendations
#
# **Best Overall Performance**: Claude Sonnet

# %% [markdown]
# ### Summary
#
# You've successfully learned how to perform systematic A/B testing evaluation for agent models. You now understand:
#
# - How to load agent configurations and recreate multiple variants
# - Creating diverse evaluation datasets from real-world scenarios
# - Running systematic evaluations with multiple built-in evaluators
# - Extracting and aggregating evaluation scores across models
# - Calculating statistical measures (mean, standard deviation)
# - Comparing model performance side-by-side
# - Analyzing cost-performance trade-offs
# - Generating actionable model selection recommendations
#
# This evaluation methodology enables data-driven decision making for model selection in production systems. By combining performance metrics with cost analysis, you can optimize for both quality and efficiency based on your specific requirements.
